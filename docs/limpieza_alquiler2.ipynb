# %%
# !pip install scipy
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: scipy in c:\users\guill\proyecto\.venv\lib\site-packages (1.14.1)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: c:\Users\guill\proyecto\.venv\Scripts\python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\guill\proyecto\.venv\lib\site-packages (from scipy) (2.1.2)
# Requirement already satisfied: seaborn in c:\users\guill\proyecto\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\guill\proyecto\.venv\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\guill\proyecto\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\guill\proyecto\.venv\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\guill\proyecto\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\guill\proyecto\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: c:\Users\guill\proyecto\.venv\Scripts\python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\guill\proyecto\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\guill\proyecto\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: c:\Users\guill\proyecto\.venv\Scripts\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from itertools import combinations
from scipy.stats import shapiro

# %%
alquiler = pd.read_csv("inmuebles_alquiler.csv")

# %%
df = alquiler.copy()

# %%
df
# Out:
#                                         id  \
# 0     d5c4c62a-f422-430a-bb28-ffd2003bde80
# 1     4447b365-9ad9-40e7-8a57-8019611cf4ce
# 2     2cd188dc-43db-4bb8-87ea-15e72ec27b60
# 3     1ccbb1b1-7a79-4c70-85f2-354dc10b354a
# 4     18c4c00d-98f9-40dd-be9e-3a012b63d9b1
# ...                                    ...
# 1981  cb7da359-204c-415f-999a-75b979b35d61
# 1982  8e56eaf2-5c4c-426c-8501-e9114045f3e9
# 1983  882079aa-e895-4a7a-82eb-5736a3386069
# 1984  c67c8dd7-b917-45ac-9702-d3a3253fc725
# 1985  9e370b30-8e3c-45b4-b5fb-aaba4bf29c2c
#
#                                             Descripción  \
# 0                  Casa adosada en alquiler en Sector B
# 1             Piso en alquiler en Calle de Vista Alegre
# 2             Casa unifamiliar en alquiler en Calle XIX
# 3            Piso en alquiler en Zona Avenida de Europa
# 4                   Chalet en alquiler en Núcleo Urbano
# ...                                                 ...
# 1981  Apartamento en alquiler en Avenida de Montes d...
# 1982               Piso en alquiler en Calle de Sagasta
# 1983   Loft en alquiler en Calle del Cerro del Murmullo
# 1984                           Piso en alquiler en Meco
# 1985  Alquiler de pisos en Prosperidad, Distrito Cha...
#
#                                            Localización  \
# 0                         Sector B (Boadilla del Monte)
# 1     Somosaguas-Húmera-Los Ángeles (Pozuelo de Alar...
# 2        Las Matas-Los Peñascales (Las Rozas de Madrid)
# 3           Zona Avenida de Europa (Pozuelo de Alarcón)
# 4               Núcleo Urbano (Villanueva de la Cañada)
# ...                                                 ...
# 1981  Ciudalcampo-Fuente del Fresno (San Sebastián d...
# 1982  Justicia-Chueca (Distrito Centro. Madrid Capital)
# 1983  Ensanche de Vallecas-Valdecarros (Distrito Vil...
# 1984                                               Meco
# 1985                         Sé el primero en enterarte
#
#                                                  Enlace Precio  \
# 0     https://www.pisos.com/alquilar/casa_adosada-se...  3.600
# 1     https://www.pisos.com/alquilar/piso-somosaguas...  1.450
# 2     https://www.pisos.com/alquilar/casa_unifamilia...  4.000
# 3     https://www.pisos.com/alquilar/piso-zona_aveni...  1.400
# 4     https://www.pisos.com/alquilar/chalet-villanue...  2.700
# ...                                                 ...    ...
# 1981  https://www.pisos.com/alquilar/apartamento-ciu...  1.700
# 1982  https://www.pisos.com/alquilar/piso-justicia_c...  4.100
# 1983  https://www.pisos.com/alquilar/loft-ensanche_d...    900
# 1984  https://www.pisos.com/alquilar/piso-meco_centr...    750
# 1985  https://www.pisos.com/alquilar/piso-chamartin_...    NaN
#
#      Superficie Construida               Última Actualización  \
# 0                      448  Anuncio actualizado el 21/10/2024
# 1                       69  Anuncio actualizado el 04/11/2024
# 2                      600  Anuncio actualizado el 04/11/2024
# 3                       65  Anuncio actualizado el 04/11/2024
# 4                      329  Anuncio actualizado el 28/10/2024
# ...                    ...                                ...
# 1981                   101  Anuncio actualizado el 04/11/2024
# 1982                   110  Anuncio actualizado el 04/11/2024
# 1983                    49  Anuncio actualizado el 04/11/2024
# 1984                    47  Anuncio actualizado el 04/11/2024
# 1985                   NaN                                NaN
#
#           Consumo Energético               Emisiones CO2  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# ...                      ...                         ...
# 1981  Consumo:126 kWh/m² año  Emisiones:12 Kg CO₂/m² año
# 1982                     NaN                         NaN
# 1983                     NaN                         NaN
# 1984                     NaN                         NaN
# 1985                     NaN                         NaN
#
#                                         Características Tipo de operación  \
# 0     [('Superficie construida:', '448 m²'), ('Habit...          Alquiler
# 1     [('Superficie construida:', '69 m²'), ('Superf...          Alquiler
# 2     [('Superficie construida:', '600 m²'), ('Super...          Alquiler
# 3     [('Superficie construida:', '65 m²'), ('Habita...          Alquiler
# 4     [('Superficie construida:', '329 m²'), ('Super...          Alquiler
# ...                                                 ...               ...
# 1981  [('Superficie construida:', '101 m²'), ('Habit...          Alquiler
# 1982  [('Superficie construida:', '110 m²'), ('Super...          Alquiler
# 1983  [('Superficie construida:', '49 m²'), ('Superf...          Alquiler
# 1984  [('Superficie construida:', '47 m²'), ('Habita...          Alquiler
# 1985                                                NaN          Alquiler
#
#                timestamp_scrapeo
# 0     2024-11-04T11:42:25.912524
# 1     2024-11-04T11:42:34.398206
# 2     2024-11-04T11:42:40.242927
# 3     2024-11-04T11:42:45.825335
# 4     2024-11-04T11:42:51.662813
# ...                          ...
# 1981  2024-11-04T15:35:40.393501
# 1982  2024-11-04T15:35:47.964623
# 1983  2024-11-04T15:35:55.661331
# 1984  2024-11-04T15:36:02.652517
# 1985  2024-11-04T15:36:10.161803
#
# [1986 rows x 12 columns]

# %%
df.head()
# Out:
#                                      id  \
# 0  d5c4c62a-f422-430a-bb28-ffd2003bde80
# 1  4447b365-9ad9-40e7-8a57-8019611cf4ce
# 2  2cd188dc-43db-4bb8-87ea-15e72ec27b60
# 3  1ccbb1b1-7a79-4c70-85f2-354dc10b354a
# 4  18c4c00d-98f9-40dd-be9e-3a012b63d9b1
#
#                                   Descripción  \
# 0        Casa adosada en alquiler en Sector B
# 1   Piso en alquiler en Calle de Vista Alegre
# 2   Casa unifamiliar en alquiler en Calle XIX
# 3  Piso en alquiler en Zona Avenida de Europa
# 4         Chalet en alquiler en Núcleo Urbano
#
#                                         Localización  \
# 0                      Sector B (Boadilla del Monte)
# 1  Somosaguas-Húmera-Los Ángeles (Pozuelo de Alar...
# 2     Las Matas-Los Peñascales (Las Rozas de Madrid)
# 3        Zona Avenida de Europa (Pozuelo de Alarcón)
# 4            Núcleo Urbano (Villanueva de la Cañada)
#
#                                               Enlace Precio  \
# 0  https://www.pisos.com/alquilar/casa_adosada-se...  3.600
# 1  https://www.pisos.com/alquilar/piso-somosaguas...  1.450
# 2  https://www.pisos.com/alquilar/casa_unifamilia...  4.000
# 3  https://www.pisos.com/alquilar/piso-zona_aveni...  1.400
# 4  https://www.pisos.com/alquilar/chalet-villanue...  2.700
#
#   Superficie Construida               Última Actualización Consumo Energético  \
# 0                   448  Anuncio actualizado el 21/10/2024                NaN
# 1                    69  Anuncio actualizado el 04/11/2024                NaN
# 2                   600  Anuncio actualizado el 04/11/2024                NaN
# 3                    65  Anuncio actualizado el 04/11/2024                NaN
# 4                   329  Anuncio actualizado el 28/10/2024                NaN
#
#   Emisiones CO2                                    Características  \
# 0           NaN  [('Superficie construida:', '448 m²'), ('Habit...
# 1           NaN  [('Superficie construida:', '69 m²'), ('Superf...
# 2           NaN  [('Superficie construida:', '600 m²'), ('Super...
# 3           NaN  [('Superficie construida:', '65 m²'), ('Habita...
# 4           NaN  [('Superficie construida:', '329 m²'), ('Super...
#
#   Tipo de operación           timestamp_scrapeo
# 0          Alquiler  2024-11-04T11:42:25.912524
# 1          Alquiler  2024-11-04T11:42:34.398206
# 2          Alquiler  2024-11-04T11:42:40.242927
# 3          Alquiler  2024-11-04T11:42:45.825335
# 4          Alquiler  2024-11-04T11:42:51.662813

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1986 non-null   object
#  1   Descripción            1986 non-null   object
#  2   Localización           1986 non-null   object
#  3   Enlace                 1986 non-null   object
#  4   Precio                 1985 non-null   object
#  5   Superficie Construida  1985 non-null   object
#  6   Última Actualización   1985 non-null   object
#  7   Consumo Energético     541 non-null    object
#  8   Emisiones CO2          541 non-null    object
#  9   Características        1985 non-null   object
#  10  Tipo de operación      1986 non-null   object
#  11  timestamp_scrapeo      1986 non-null   object
# dtypes: object(12)
# memory usage: 186.3+ KB

# %%
# Función para extraer las características de la columna y convertirlas en columnas separadas
def extraer_caracteristicas(fila):
    # Elimina los caracteres adicionales para convertir la cadena en una lista de tuplas
    fila = fila.strip("[]")  # Elimina los corchetes externos
    elementos = fila.split("), (")  # Divide la cadena en tuplas individuales
    
    datos_extraidos = {}
    for elemento in elementos:
        # Divide cada elemento en clave y valor
        clave, valor = elemento.split(", ", 1)
        clave = clave.replace("(", "").replace("'", "").strip()  # Limpia clave
        valor = valor.replace(")", "").replace("'", "").strip()  # Limpia valor
        datos_extraidos[clave.strip(':')] = valor  # Remueve ':' del final de la clave si está presente
    return datos_extraidos

# Aplicar la función a la columna 'Características' y expandir en columnas separadas
caracteristicas_df = df['Características'].dropna().apply(extraer_caracteristicas)
caracteristicas_expandidas = pd.json_normalize(caracteristicas_df)

# Combinar las columnas expandidas con el DataFrame original (elimina la columna 'Características' original)
df_limpio = pd.concat([df.drop(columns=['Características']), caracteristicas_expandidas], axis=1)

# Guardar el DataFrame limpio en un nuevo archivo CSV si deseas conservarlo
df_limpio.to_csv('inmuebles_alquiler_limpio.csv', index=False)

# Visualización del resultado
print(df_limpio.head())
# Out:
#                                      id  \
# 0  d5c4c62a-f422-430a-bb28-ffd2003bde80
# 1  4447b365-9ad9-40e7-8a57-8019611cf4ce
# 2  2cd188dc-43db-4bb8-87ea-15e72ec27b60
# 3  1ccbb1b1-7a79-4c70-85f2-354dc10b354a
# 4  18c4c00d-98f9-40dd-be9e-3a012b63d9b1
#
#                                   Descripción  \
# 0        Casa adosada en alquiler en Sector B
# 1   Piso en alquiler en Calle de Vista Alegre
# 2   Casa unifamiliar en alquiler en Calle XIX
# 3  Piso en alquiler en Zona Avenida de Europa
# 4         Chalet en alquiler en Núcleo Urbano
#
#                                         Localización  \
# 0                      Sector B (Boadilla del Monte)
# 1  Somosaguas-Húmera-Los Ángeles (Pozuelo de Alar...
# 2     Las Matas-Los Peñascales (Las Rozas de Madrid)
# 3        Zona Avenida de Europa (Pozuelo de Alarcón)
# 4            Núcleo Urbano (Villanueva de la Cañada)
#
#                                               Enlace Precio  \
# 0  https://www.pisos.com/alquilar/casa_adosada-se...  3.600
# 1  https://www.pisos.com/alquilar/piso-somosaguas...  1.450
# 2  https://www.pisos.com/alquilar/casa_unifamilia...  4.000
# 3  https://www.pisos.com/alquilar/piso-zona_aveni...  1.400
# 4  https://www.pisos.com/alquilar/chalet-villanue...  2.700
#
#   Superficie Construida               Última Actualización Consumo Energético  \
# 0                   448  Anuncio actualizado el 21/10/2024                NaN
# 1                    69  Anuncio actualizado el 04/11/2024                NaN
# 2                   600  Anuncio actualizado el 04/11/2024                NaN
# 3                    65  Anuncio actualizado el 04/11/2024                NaN
# 4                   329  Anuncio actualizado el 28/10/2024                NaN
#
#   Emisiones CO2 Tipo de operación  ... Tipo de casa          Antigüedad  \
# 0           NaN          Alquiler  ...      Adosada     Menos de 5 años
# 1           NaN          Alquiler  ...          NaN     Menos de 5 años
# 2           NaN          Alquiler  ...  Unifamiliar   Entre 5 y 10 años
# 3           NaN          Alquiler  ...          NaN                 NaN
# 4           NaN          Alquiler  ...          NaN  Entre 20 y 30 años
#
#      Conservación              Referencia Superficie útil Planta  \
# 0  En buen estado            TC170-581681             NaN    NaN
# 1  En buen estado             2805-002408           48 m²     1ª
# 2  En buen estado             2805-002317          600 m²    NaN
# 3             NaN  IF5032-avda-1d-V T 40m             NaN     2ª
# 4             NaN            IF7144-ALQIT             NaN    NaN
#
#   Superficie solar Gastos de comunidad Interior Exterior
# 0              NaN                 NaN      NaN      NaN
# 1              NaN                 NaN      NaN      NaN
# 2              NaN                 NaN      NaN      NaN
# 3              NaN                 NaN      NaN      NaN
# 4           367 m²                 NaN      NaN      NaN
#
# [5 rows x 24 columns]

# %%
df_limpio
# Out:
#                                         id  \
# 0     d5c4c62a-f422-430a-bb28-ffd2003bde80
# 1     4447b365-9ad9-40e7-8a57-8019611cf4ce
# 2     2cd188dc-43db-4bb8-87ea-15e72ec27b60
# 3     1ccbb1b1-7a79-4c70-85f2-354dc10b354a
# 4     18c4c00d-98f9-40dd-be9e-3a012b63d9b1
# ...                                    ...
# 1981  cb7da359-204c-415f-999a-75b979b35d61
# 1982  8e56eaf2-5c4c-426c-8501-e9114045f3e9
# 1983  882079aa-e895-4a7a-82eb-5736a3386069
# 1984  c67c8dd7-b917-45ac-9702-d3a3253fc725
# 1985  9e370b30-8e3c-45b4-b5fb-aaba4bf29c2c
#
#                                             Descripción  \
# 0                  Casa adosada en alquiler en Sector B
# 1             Piso en alquiler en Calle de Vista Alegre
# 2             Casa unifamiliar en alquiler en Calle XIX
# 3            Piso en alquiler en Zona Avenida de Europa
# 4                   Chalet en alquiler en Núcleo Urbano
# ...                                                 ...
# 1981  Apartamento en alquiler en Avenida de Montes d...
# 1982               Piso en alquiler en Calle de Sagasta
# 1983   Loft en alquiler en Calle del Cerro del Murmullo
# 1984                           Piso en alquiler en Meco
# 1985  Alquiler de pisos en Prosperidad, Distrito Cha...
#
#                                            Localización  \
# 0                         Sector B (Boadilla del Monte)
# 1     Somosaguas-Húmera-Los Ángeles (Pozuelo de Alar...
# 2        Las Matas-Los Peñascales (Las Rozas de Madrid)
# 3           Zona Avenida de Europa (Pozuelo de Alarcón)
# 4               Núcleo Urbano (Villanueva de la Cañada)
# ...                                                 ...
# 1981  Ciudalcampo-Fuente del Fresno (San Sebastián d...
# 1982  Justicia-Chueca (Distrito Centro. Madrid Capital)
# 1983  Ensanche de Vallecas-Valdecarros (Distrito Vil...
# 1984                                               Meco
# 1985                         Sé el primero en enterarte
#
#                                                  Enlace Precio  \
# 0     https://www.pisos.com/alquilar/casa_adosada-se...  3.600
# 1     https://www.pisos.com/alquilar/piso-somosaguas...  1.450
# 2     https://www.pisos.com/alquilar/casa_unifamilia...  4.000
# 3     https://www.pisos.com/alquilar/piso-zona_aveni...  1.400
# 4     https://www.pisos.com/alquilar/chalet-villanue...  2.700
# ...                                                 ...    ...
# 1981  https://www.pisos.com/alquilar/apartamento-ciu...  1.700
# 1982  https://www.pisos.com/alquilar/piso-justicia_c...  4.100
# 1983  https://www.pisos.com/alquilar/loft-ensanche_d...    900
# 1984  https://www.pisos.com/alquilar/piso-meco_centr...    750
# 1985  https://www.pisos.com/alquilar/piso-chamartin_...    NaN
#
#      Superficie Construida               Última Actualización  \
# 0                      448  Anuncio actualizado el 21/10/2024
# 1                       69  Anuncio actualizado el 04/11/2024
# 2                      600  Anuncio actualizado el 04/11/2024
# 3                       65  Anuncio actualizado el 04/11/2024
# 4                      329  Anuncio actualizado el 28/10/2024
# ...                    ...                                ...
# 1981                   101  Anuncio actualizado el 04/11/2024
# 1982                   110  Anuncio actualizado el 04/11/2024
# 1983                    49  Anuncio actualizado el 04/11/2024
# 1984                    47  Anuncio actualizado el 04/11/2024
# 1985                   NaN                                NaN
#
#           Consumo Energético               Emisiones CO2 Tipo de operación  \
# 0                        NaN                         NaN          Alquiler
# 1                        NaN                         NaN          Alquiler
# 2                        NaN                         NaN          Alquiler
# 3                        NaN                         NaN          Alquiler
# 4                        NaN                         NaN          Alquiler
# ...                      ...                         ...               ...
# 1981  Consumo:126 kWh/m² año  Emisiones:12 Kg CO₂/m² año          Alquiler
# 1982                     NaN                         NaN          Alquiler
# 1983                     NaN                         NaN          Alquiler
# 1984                     NaN                         NaN          Alquiler
# 1985                     NaN                         NaN          Alquiler
#
#       ... Tipo de casa          Antigüedad    Conservación  \
# 0     ...      Adosada     Menos de 5 años  En buen estado
# 1     ...          NaN     Menos de 5 años  En buen estado
# 2     ...  Unifamiliar   Entre 5 y 10 años  En buen estado
# 3     ...          NaN                 NaN             NaN
# 4     ...          NaN  Entre 20 y 30 años             NaN
# ...   ...          ...                 ...             ...
# 1981  ...          NaN     Menos de 5 años             NaN
# 1982  ...          NaN  Entre 30 y 50 años       Reformado
# 1983  ...          NaN  Entre 10 y 20 años             NaN
# 1984  ...          NaN  Entre 20 y 30 años             NaN
# 1985  ...          NaN                 NaN             NaN
#
#                      Referencia Superficie útil Planta Superficie solar  \
# 0                  TC170-581681             NaN    NaN              NaN
# 1                   2805-002408           48 m²     1ª              NaN
# 2                   2805-002317          600 m²    NaN              NaN
# 3        IF5032-avda-1d-V T 40m             NaN     2ª              NaN
# 4                  IF7144-ALQIT             NaN    NaN           367 m²
# ...                         ...             ...    ...              ...
# 1981  IF77045-I-00L4HH-W-02XKL0             NaN    NaN              NaN
# 1982             996542-3723-JG          100 m²     3ª              NaN
# 1983           SA4390-2409/9233           30 m²   Bajo              NaN
# 1984           IF6880-1316/3738             NaN     1ª              NaN
# 1985                        NaN             NaN    NaN              NaN
#
#      Gastos de comunidad Interior Exterior
# 0                    NaN      NaN      NaN
# 1                    NaN      NaN      NaN
# 2                    NaN      NaN      NaN
# 3                    NaN      NaN      NaN
# 4                    NaN      NaN      NaN
# ...                  ...      ...      ...
# 1981                 NaN      NaN      NaN
# 1982                 NaN      NaN      NaN
# 1983                 NaN      NaN      NaN
# 1984                 NaN      NaN      NaN
# 1985                 NaN      NaN      NaN
#
# [1986 rows x 24 columns]

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1986 non-null   object
#  1   Descripción            1986 non-null   object
#  2   Localización           1986 non-null   object
#  3   Enlace                 1986 non-null   object
#  4   Precio                 1985 non-null   object
#  5   Superficie Construida  1985 non-null   object
#  6   Última Actualización   1985 non-null   object
#  7   Consumo Energético     541 non-null    object
#  8   Emisiones CO2          541 non-null    object
#  9   Tipo de operación      1986 non-null   object
#  10  timestamp_scrapeo      1986 non-null   object
#  11  Superficie construida  1978 non-null   object
#  12  Habitaciones           1909 non-null   object
#  13  Baños                  1925 non-null   object
#  14  Tipo de casa           38 non-null     object
#  15  Antigüedad             824 non-null    object
#  16  Conservación           1303 non-null   object
#  17  Referencia             1985 non-null   object
#  18  Superficie útil        773 non-null    object
#  19  Planta                 1511 non-null   object
#  20  Superficie solar       69 non-null     object
#  21  Gastos de comunidad    38 non-null     object
#  22  Interior               4 non-null      object
#  23  Exterior               7 non-null      object
# dtypes: object(24)
# memory usage: 372.5+ KB

# %%
# Lista de tipos de casa que queremos identificar
tipos_casa = ["Piso", "Chalet", "Adosado", "Casa", "Estudio", "Dúplex"]

# Función para extraer el tipo de casa de la descripción
def extraer_tipo_casa(descripcion):
    for tipo in tipos_casa:
        if tipo.lower() in descripcion.lower():
            return tipo
    return "Otro"  # Valor por defecto si no coincide con ninguno de los tipos en la lista

# Crear una nueva columna en el DataFrame con el tipo de casa
df_limpio['Tipo de Casa'] = df_limpio['Descripción'].apply(extraer_tipo_casa)

# Visualización del resultado
print(df_limpio[['Descripción', 'Tipo de Casa']].head())
# Out:
#                                   Descripción Tipo de Casa
# 0        Casa adosada en alquiler en Sector B         Casa
# 1   Piso en alquiler en Calle de Vista Alegre         Piso
# 2   Casa unifamiliar en alquiler en Calle XIX         Casa
# 3  Piso en alquiler en Zona Avenida de Europa         Piso
# 4         Chalet en alquiler en Núcleo Urbano       Chalet

# %%
df_limpio
# Out:
#                                         id  \
# 0     d5c4c62a-f422-430a-bb28-ffd2003bde80
# 1     4447b365-9ad9-40e7-8a57-8019611cf4ce
# 2     2cd188dc-43db-4bb8-87ea-15e72ec27b60
# 3     1ccbb1b1-7a79-4c70-85f2-354dc10b354a
# 4     18c4c00d-98f9-40dd-be9e-3a012b63d9b1
# ...                                    ...
# 1981  cb7da359-204c-415f-999a-75b979b35d61
# 1982  8e56eaf2-5c4c-426c-8501-e9114045f3e9
# 1983  882079aa-e895-4a7a-82eb-5736a3386069
# 1984  c67c8dd7-b917-45ac-9702-d3a3253fc725
# 1985  9e370b30-8e3c-45b4-b5fb-aaba4bf29c2c
#
#                                             Descripción  \
# 0                  Casa adosada en alquiler en Sector B
# 1             Piso en alquiler en Calle de Vista Alegre
# 2             Casa unifamiliar en alquiler en Calle XIX
# 3            Piso en alquiler en Zona Avenida de Europa
# 4                   Chalet en alquiler en Núcleo Urbano
# ...                                                 ...
# 1981  Apartamento en alquiler en Avenida de Montes d...
# 1982               Piso en alquiler en Calle de Sagasta
# 1983   Loft en alquiler en Calle del Cerro del Murmullo
# 1984                           Piso en alquiler en Meco
# 1985  Alquiler de pisos en Prosperidad, Distrito Cha...
#
#                                            Localización  \
# 0                         Sector B (Boadilla del Monte)
# 1     Somosaguas-Húmera-Los Ángeles (Pozuelo de Alar...
# 2        Las Matas-Los Peñascales (Las Rozas de Madrid)
# 3           Zona Avenida de Europa (Pozuelo de Alarcón)
# 4               Núcleo Urbano (Villanueva de la Cañada)
# ...                                                 ...
# 1981  Ciudalcampo-Fuente del Fresno (San Sebastián d...
# 1982  Justicia-Chueca (Distrito Centro. Madrid Capital)
# 1983  Ensanche de Vallecas-Valdecarros (Distrito Vil...
# 1984                                               Meco
# 1985                         Sé el primero en enterarte
#
#                                                  Enlace Precio  \
# 0     https://www.pisos.com/alquilar/casa_adosada-se...  3.600
# 1     https://www.pisos.com/alquilar/piso-somosaguas...  1.450
# 2     https://www.pisos.com/alquilar/casa_unifamilia...  4.000
# 3     https://www.pisos.com/alquilar/piso-zona_aveni...  1.400
# 4     https://www.pisos.com/alquilar/chalet-villanue...  2.700
# ...                                                 ...    ...
# 1981  https://www.pisos.com/alquilar/apartamento-ciu...  1.700
# 1982  https://www.pisos.com/alquilar/piso-justicia_c...  4.100
# 1983  https://www.pisos.com/alquilar/loft-ensanche_d...    900
# 1984  https://www.pisos.com/alquilar/piso-meco_centr...    750
# 1985  https://www.pisos.com/alquilar/piso-chamartin_...    NaN
#
#      Superficie Construida               Última Actualización  \
# 0                      448  Anuncio actualizado el 21/10/2024
# 1                       69  Anuncio actualizado el 04/11/2024
# 2                      600  Anuncio actualizado el 04/11/2024
# 3                       65  Anuncio actualizado el 04/11/2024
# 4                      329  Anuncio actualizado el 28/10/2024
# ...                    ...                                ...
# 1981                   101  Anuncio actualizado el 04/11/2024
# 1982                   110  Anuncio actualizado el 04/11/2024
# 1983                    49  Anuncio actualizado el 04/11/2024
# 1984                    47  Anuncio actualizado el 04/11/2024
# 1985                   NaN                                NaN
#
#           Consumo Energético               Emisiones CO2 Tipo de operación  \
# 0                        NaN                         NaN          Alquiler
# 1                        NaN                         NaN          Alquiler
# 2                        NaN                         NaN          Alquiler
# 3                        NaN                         NaN          Alquiler
# 4                        NaN                         NaN          Alquiler
# ...                      ...                         ...               ...
# 1981  Consumo:126 kWh/m² año  Emisiones:12 Kg CO₂/m² año          Alquiler
# 1982                     NaN                         NaN          Alquiler
# 1983                     NaN                         NaN          Alquiler
# 1984                     NaN                         NaN          Alquiler
# 1985                     NaN                         NaN          Alquiler
#
#       ...          Antigüedad    Conservación                 Referencia  \
# 0     ...     Menos de 5 años  En buen estado               TC170-581681
# 1     ...     Menos de 5 años  En buen estado                2805-002408
# 2     ...   Entre 5 y 10 años  En buen estado                2805-002317
# 3     ...                 NaN             NaN     IF5032-avda-1d-V T 40m
# 4     ...  Entre 20 y 30 años             NaN               IF7144-ALQIT
# ...   ...                 ...             ...                        ...
# 1981  ...     Menos de 5 años             NaN  IF77045-I-00L4HH-W-02XKL0
# 1982  ...  Entre 30 y 50 años       Reformado             996542-3723-JG
# 1983  ...  Entre 10 y 20 años             NaN           SA4390-2409/9233
# 1984  ...  Entre 20 y 30 años             NaN           IF6880-1316/3738
# 1985  ...                 NaN             NaN                        NaN
#
#      Superficie útil Planta Superficie solar Gastos de comunidad Interior  \
# 0                NaN    NaN              NaN                 NaN      NaN
# 1              48 m²     1ª              NaN                 NaN      NaN
# 2             600 m²    NaN              NaN                 NaN      NaN
# 3                NaN     2ª              NaN                 NaN      NaN
# 4                NaN    NaN           367 m²                 NaN      NaN
# ...              ...    ...              ...                 ...      ...
# 1981             NaN    NaN              NaN                 NaN      NaN
# 1982          100 m²     3ª              NaN                 NaN      NaN
# 1983           30 m²   Bajo              NaN                 NaN      NaN
# 1984             NaN     1ª              NaN                 NaN      NaN
# 1985             NaN    NaN              NaN                 NaN      NaN
#
#      Exterior Tipo de Casa
# 0         NaN         Casa
# 1         NaN         Piso
# 2         NaN         Casa
# 3         NaN         Piso
# 4         NaN       Chalet
# ...       ...          ...
# 1981      NaN         Otro
# 1982      NaN         Piso
# 1983      NaN         Otro
# 1984      NaN         Piso
# 1985      NaN         Piso
#
# [1986 rows x 25 columns]

# %%
df_limpio = df_limpio.drop(columns=["Superficie Construida","Tipo de casa","Referencia","Gastos de comunidad","Superficie solar","Interior","Exterior"])

# %%
df_limpio
# Out:
#                                         id  \
# 0     d5c4c62a-f422-430a-bb28-ffd2003bde80
# 1     4447b365-9ad9-40e7-8a57-8019611cf4ce
# 2     2cd188dc-43db-4bb8-87ea-15e72ec27b60
# 3     1ccbb1b1-7a79-4c70-85f2-354dc10b354a
# 4     18c4c00d-98f9-40dd-be9e-3a012b63d9b1
# ...                                    ...
# 1981  cb7da359-204c-415f-999a-75b979b35d61
# 1982  8e56eaf2-5c4c-426c-8501-e9114045f3e9
# 1983  882079aa-e895-4a7a-82eb-5736a3386069
# 1984  c67c8dd7-b917-45ac-9702-d3a3253fc725
# 1985  9e370b30-8e3c-45b4-b5fb-aaba4bf29c2c
#
#                                             Descripción  \
# 0                  Casa adosada en alquiler en Sector B
# 1             Piso en alquiler en Calle de Vista Alegre
# 2             Casa unifamiliar en alquiler en Calle XIX
# 3            Piso en alquiler en Zona Avenida de Europa
# 4                   Chalet en alquiler en Núcleo Urbano
# ...                                                 ...
# 1981  Apartamento en alquiler en Avenida de Montes d...
# 1982               Piso en alquiler en Calle de Sagasta
# 1983   Loft en alquiler en Calle del Cerro del Murmullo
# 1984                           Piso en alquiler en Meco
# 1985  Alquiler de pisos en Prosperidad, Distrito Cha...
#
#                                            Localización  \
# 0                         Sector B (Boadilla del Monte)
# 1     Somosaguas-Húmera-Los Ángeles (Pozuelo de Alar...
# 2        Las Matas-Los Peñascales (Las Rozas de Madrid)
# 3           Zona Avenida de Europa (Pozuelo de Alarcón)
# 4               Núcleo Urbano (Villanueva de la Cañada)
# ...                                                 ...
# 1981  Ciudalcampo-Fuente del Fresno (San Sebastián d...
# 1982  Justicia-Chueca (Distrito Centro. Madrid Capital)
# 1983  Ensanche de Vallecas-Valdecarros (Distrito Vil...
# 1984                                               Meco
# 1985                         Sé el primero en enterarte
#
#                                                  Enlace Precio  \
# 0     https://www.pisos.com/alquilar/casa_adosada-se...  3.600
# 1     https://www.pisos.com/alquilar/piso-somosaguas...  1.450
# 2     https://www.pisos.com/alquilar/casa_unifamilia...  4.000
# 3     https://www.pisos.com/alquilar/piso-zona_aveni...  1.400
# 4     https://www.pisos.com/alquilar/chalet-villanue...  2.700
# ...                                                 ...    ...
# 1981  https://www.pisos.com/alquilar/apartamento-ciu...  1.700
# 1982  https://www.pisos.com/alquilar/piso-justicia_c...  4.100
# 1983  https://www.pisos.com/alquilar/loft-ensanche_d...    900
# 1984  https://www.pisos.com/alquilar/piso-meco_centr...    750
# 1985  https://www.pisos.com/alquilar/piso-chamartin_...    NaN
#
#                    Última Actualización      Consumo Energético  \
# 0     Anuncio actualizado el 21/10/2024                     NaN
# 1     Anuncio actualizado el 04/11/2024                     NaN
# 2     Anuncio actualizado el 04/11/2024                     NaN
# 3     Anuncio actualizado el 04/11/2024                     NaN
# 4     Anuncio actualizado el 28/10/2024                     NaN
# ...                                 ...                     ...
# 1981  Anuncio actualizado el 04/11/2024  Consumo:126 kWh/m² año
# 1982  Anuncio actualizado el 04/11/2024                     NaN
# 1983  Anuncio actualizado el 04/11/2024                     NaN
# 1984  Anuncio actualizado el 04/11/2024                     NaN
# 1985                                NaN                     NaN
#
#                    Emisiones CO2 Tipo de operación  \
# 0                            NaN          Alquiler
# 1                            NaN          Alquiler
# 2                            NaN          Alquiler
# 3                            NaN          Alquiler
# 4                            NaN          Alquiler
# ...                          ...               ...
# 1981  Emisiones:12 Kg CO₂/m² año          Alquiler
# 1982                         NaN          Alquiler
# 1983                         NaN          Alquiler
# 1984                         NaN          Alquiler
# 1985                         NaN          Alquiler
#
#                timestamp_scrapeo Superficie construida Habitaciones Baños  \
# 0     2024-11-04T11:42:25.912524                448 m²            5     2
# 1     2024-11-04T11:42:34.398206                 69 m²            1     1
# 2     2024-11-04T11:42:40.242927                600 m²            6     7
# 3     2024-11-04T11:42:45.825335                 65 m²            1     1
# 4     2024-11-04T11:42:51.662813                329 m²            5     3
# ...                          ...                   ...          ...   ...
# 1981  2024-11-04T15:35:40.393501                101 m²            2     1
# 1982  2024-11-04T15:35:47.964623                110 m²            2     2
# 1983  2024-11-04T15:35:55.661331                 49 m²          NaN     1
# 1984  2024-11-04T15:36:02.652517                 47 m²            1     1
# 1985  2024-11-04T15:36:10.161803                   NaN          NaN   NaN
#
#               Antigüedad    Conservación Superficie útil Planta Tipo de Casa
# 0        Menos de 5 años  En buen estado             NaN    NaN         Casa
# 1        Menos de 5 años  En buen estado           48 m²     1ª         Piso
# 2      Entre 5 y 10 años  En buen estado          600 m²    NaN         Casa
# 3                    NaN             NaN             NaN     2ª         Piso
# 4     Entre 20 y 30 años             NaN             NaN    NaN       Chalet
# ...                  ...             ...             ...    ...          ...
# 1981     Menos de 5 años             NaN             NaN    NaN         Otro
# 1982  Entre 30 y 50 años       Reformado          100 m²     3ª         Piso
# 1983  Entre 10 y 20 años             NaN           30 m²   Bajo         Otro
# 1984  Entre 20 y 30 años             NaN             NaN     1ª         Piso
# 1985                 NaN             NaN             NaN    NaN         Piso
#
# [1986 rows x 18 columns]

# %%
# Extraer la fecha de la columna 'Última Actualización' y convertirla a tipo datetime
df_limpio['Última Actualización'] = df_limpio['Última Actualización'].str.extract(r'(\d{2}/\d{2}/\d{4})')
df_limpio['Última Actualización'] = pd.to_datetime(df_limpio['Última Actualización'], format='%d/%m/%Y')

# Verificar el resultado
print(df_limpio['Última Actualización'].head())
# Out:
# 0   2024-10-21
# 1   2024-11-04
# 2   2024-11-04
# 3   2024-11-04
# 4   2024-10-28
# Name: Última Actualización, dtype: datetime64[ns]

# %%
# Eliminar filas donde 'Precio' es NaN
df_limpio = df_limpio.dropna(subset=['Precio'])

# %%
# Filtrar filas en 'Precio' que contienen caracteres no numéricos
valores_no_numericos = df_limpio[~df_limpio['Precio'].str.replace('.', '', regex=False).str.replace(',', '', regex=False).str.isnumeric()]

# Mostrar los resultados
print(valores_no_numericos[['Precio']])
# Out:
#      Precio
# 1911      A
# 1912      A
# 1922      A
# 1929      A
# 1933      A
# 1935      A
# 1950      A
# 1980      A

# %%
# Mostrar filas en los índices específicos
indices_a = [1911, 1912,1922, 1929, 1933, 1935, 1950, 1980]
print(df.loc[indices_a])
# Out:
#                                         id  \
# 1911  8dc9d097-a26a-4c8d-89e6-f6f22e6eb7f7
# 1912  16ebd821-9396-49ed-8626-9c0d32478fd6
# 1922  50da2e88-d253-457c-beb7-cad88aae4064
# 1929  67e824de-fa1c-41e2-a40b-05c31d4bf836
# 1933  9551b139-3878-4bf8-9d33-89ac7872ca7b
# 1935  4c35f3fd-9077-444d-801f-4a82e143d096
# 1950  fa029969-53aa-43ca-9eba-67470f4c73f9
# 1980  d1f4cee2-dca3-4631-aa3b-d732d70e954d
#
#                                             Descripción  \
# 1911             Piso en alquiler en Puente de Vallecas
# 1912             Apartamento en alquiler en Almendrales
# 1922        Apartamento en alquiler en Alameda de Osuna
# 1929  Casa en alquiler en Ciudalcampo-Fuente del Fresno
# 1933                  Piso en alquiler en Ciudad Lineal
# 1935                       Piso en alquiler en Vallecas
# 1950  Piso en alquiler en Calle de Casado del Alisal...
# 1980    Apartamento en alquiler en Calle de Istúriz, 12
#
#                                            Localización  \
# 1911               ¡Vaya! Esta propiedad no tiene fotos
# 1912               ¡Vaya! Esta propiedad no tiene fotos
# 1922               ¡Vaya! Esta propiedad no tiene fotos
# 1929  Ciudalcampo-Fuente del Fresno (San Sebastián d...
# 1933               ¡Vaya! Esta propiedad no tiene fotos
# 1935               ¡Vaya! Esta propiedad no tiene fotos
# 1950        Jerónimos (Distrito Retiro. Madrid Capital)
# 1980   Cuatro Caminos (Distrito Tetuán. Madrid Capital)
#
#                                                  Enlace Precio  \
# 1911  https://www.pisos.com/alquilar/piso-puente_de_...      A
# 1912  https://www.pisos.com/alquilar/apartamento-opa...      A
# 1922  https://www.pisos.com/alquilar/apartamento-ala...      A
# 1929  https://www.pisos.com/alquilar/casa-ciudalcamp...      A
# 1933  https://www.pisos.com/alquilar/piso-ciudad_lin...      A
# 1935  https://www.pisos.com/alquilar/piso-ensanche_d...      A
# 1950  https://www.pisos.com/alquilar/piso-jeronimos2...      A
# 1980  https://www.pisos.com/alquilar/apartamento-tet...      A
#
#      Superficie Construida               Última Actualización  \
# 1911                  Bajo  Anuncio actualizado el 18/09/2024
# 1912                  Bajo  Anuncio actualizado el 04/09/2024
# 1922                  Bajo  Anuncio actualizado el 31/10/2024
# 1929                   960  Anuncio actualizado el 31/10/2024
# 1933                  Bajo  Anuncio actualizado el 09/10/2024
# 1935                  Bajo  Anuncio actualizado el 26/09/2024
# 1950                   144  Anuncio actualizado el 04/10/2024
# 1980                    70  Anuncio actualizado el 06/06/2024
#
#      Consumo Energético Emisiones CO2  \
# 1911                NaN           NaN
# 1912                NaN           NaN
# 1922                NaN           NaN
# 1929                NaN           NaN
# 1933                NaN           NaN
# 1935                NaN           NaN
# 1950                NaN           NaN
# 1980                NaN           NaN
#
#                                         Características Tipo de operación  \
# 1911  [('Planta:', 'Bajo'), ('Antigüedad:', 'Más de ...          Alquiler
# 1912  [('Planta:', 'Bajo'), ('Referencia:', 'SA4312-...          Alquiler
# 1922  [('Planta:', 'Bajo'), ('Referencia:', 'SA4312-...          Alquiler
# 1929  [('Superficie construida:', '960 m²'), ('Super...          Alquiler
# 1933  [('Planta:', 'Bajo'), ('Referencia:', 'SA4312-...          Alquiler
# 1935  [('Planta:', 'Bajo'), ('Referencia:', 'SA4312-...          Alquiler
# 1950  [('Superficie construida:', '144 m²'), ('Super...          Alquiler
# 1980  [('Superficie construida:', '70 m²'), ('Superf...          Alquiler
#
#                timestamp_scrapeo
# 1911  2024-11-04T15:27:22.317655
# 1912  2024-11-04T15:27:28.147116
# 1922  2024-11-04T15:28:41.102390
# 1929  2024-11-04T15:29:32.429722
# 1933  2024-11-04T15:30:01.701021
# 1935  2024-11-04T15:30:17.364998
# 1950  2024-11-04T15:32:03.405306
# 1980  2024-11-04T15:35:33.283780

# %%
# Usar .loc para evitar el SettingWithCopyWarning
df_limpio.loc[df_limpio['Precio'] == 'A', 'Precio'] = 0

# %%
# Limpiar valores en la columna 'Precio', eliminando puntos y comas, y convertir a float
df_limpio.loc[:, 'Precio'] = df_limpio['Precio'].replace({r'\.': '', ',': ''}, regex=True).astype(float)

# %%
df_limpio["Precio"].unique()
# Out:
# array([3600.0, 1450.0, 4000.0, 1400.0, 2700.0, 1350.0, 1147.0, 7000.0,
#        2200.0, 3750.0, 3500.0, 2300.0, 4500.0, 3000.0, 11000.0, 1500.0,
#        720.0, 1075.0, 2500.0, 1284.0, 2400.0, 12000.0, 875.0, 600.0,
#        2000.0, 4200.0, 1900.0, 3185.0, 1600.0, 2355.0, 1100.0, 2900.0,
#        5400.0, 3535.0, 1000.0, 1050.0, 1250.0, 750.0, 900.0, 1650.0,
#        4900.0, 1325.0, 1800.0, 6000.0, 1750.0, 2250.0, 5200.0, 1375.0,
#        899.0, 1490.0, 870.0, 1700.0, 995.0, 950.0, 1425.0, 1150.0, 1495.0,
#        1236.0, 5000.0, 3450.0, 2150.0, 4150.0, 1680.0, 3150.0, 1300.0,
#        2800.0, 1200.0, 2350.0, 1061.0, 4300.0, 2100.0, 700.0, 1950.0,
#        850.0, 1790.0, 3800.0, 1598.0, 4100.0, 2490.0, 6500.0, 11500.0,
#        1275.0, 890.0, 14000.0, 3400.0, 3200.0, 1190.0, 1675.0, 4950.0,
#        8000.0, 7800.0, 9500.0, 9850.0, 3155.0, 16000.0, 2080.0, 2030.0,
#        3070.0, 2210.0, 4460.0, 2600.0, 3250.0, 3635.0, 3220.0, 1820.0,
#        3435.0, 8500.0, 2310.0, 4415.0, 3465.0, 3740.0, 3080.0, 3515.0,
#        2335.0, 2755.0, 2180.0, 3350.0, 3900.0, 3570.0, 3040.0, 3585.0,
#        2305.0, 3860.0, 7500.0, 3305.0, 2945.0, 2445.0, 4025.0, 3665.0,
#        2850.0, 3485.0, 2660.0, 2895.0, 3360.0, 3830.0, 2995.0, 3140.0,
#        3735.0, 2980.0, 3075.0, 2375.0, 4420.0, 4070.0, 4180.0, 3340.0,
#        4235.0, 4630.0, 2475.0, 4125.0, 2450.0, 3245.0, 15000.0, 1865.0,
#        2750.0, 8800.0, 8300.0, 2325.0, 3700.0, 4185.0, 2435.0, 3280.0,
#        3945.0, 4040.0, 2910.0, 4065.0, 2830.0, 4055.0, 2555.0, 4030.0,
#        3445.0, 2645.0, 4050.0, 1505.0, 5500.0, 3480.0, 2010.0, 2175.0,
#        3125.0, 3950.0, 3145.0, 2120.0, 3890.0, 3395.0, 2630.0, 3300.0,
#        2485.0, 3310.0, 1493.0, 4515.0, 4560.0, 4075.0, 3645.0, 1850.0,
#        2360.0, 4225.0, 4175.0, 2455.0, 2155.0, 3610.0, 2405.0, 2275.0,
#        2875.0, 3320.0, 3100.0, 3005.0, 2780.0, 4080.0, 650.0, 2130.0,
#        2675.0, 3935.0, 2650.0, 6700.0, 4250.0, 3560.0, 10000.0, 3910.0,
#        2190.0, 2955.0, 2960.0, 18500.0, 3930.0, 4135.0, 3225.0, 3285.0,
#        3255.0, 4195.0, 2315.0, 895.0, 2950.0, 8900.0, 990.0, 2890.0,
#        2470.0, 2740.0, 1224.0, 4805.0, 2359.0, 3520.0, 2510.0, 2560.0,
#        2930.0, 4600.0, 2290.0, 4280.0, 2230.0, 4265.0, 3770.0, 680.0,
#        3550.0, 4995.0, 2385.0, 800.0, 4390.0, 2805.0, 3605.0, 3295.0,
#        3045.0, 3235.0, 3775.0, 3095.0, 2865.0, 2860.0, 3755.0, 2050.0,
#        2595.0, 3590.0, 2260.0, 3010.0, 4205.0, 4935.0, 3545.0, 2530.0,
#        3925.0, 2585.0, 3210.0, 2065.0, 2985.0, 3825.0, 4155.0, 3390.0,
#        3855.0, 6850.0, 6950.0, 2580.0, 1040.0, 2410.0, 3540.0, 4520.0,
#        3810.0, 1690.0, 3660.0, 3690.0, 2935.0, 1298.0, 1465.0, 3380.0,
#        2920.0, 1020.0, 2715.0, 3385.0, 2565.0, 2725.0, 2160.0, 2745.0,
#        12500.0, 2790.0, 4020.0, 4085.0, 3490.0, 975.0, 4700.0, 2970.0,
#        3330.0, 2665.0, 9000.0, 790.0, 3440.0, 5600.0, 940.0, 1095.0,
#        1170.0, 1135.0, 970.0, 920.0, 930.0, 1590.0, 5800.0, 1550.0, 760.0,
#        1145.0, 1080.0, 1120.0, 865.0, 980.0, 935.0, 1320.0, 1280.0,
#        1175.0, 1025.0, 6750.0, 1195.0, 1115.0, 1060.0, 1090.0, 885.0,
#        1990.0, 1005.0, 1270.0, 1125.0, 1155.0, 925.0, 4370.0, 1295.0,
#        1660.0, 6900.0, 1010.0, 1775.0, 2270.0, 1130.0, 965.0, 1240.0,
#        16500.0, 1030.0, 3990.0, 1070.0, 1015.0, 1124.0, 880.0, 1110.0,
#        3530.0, 2640.0, 9250.0, 2090.0, 1390.0, 945.0, 830.0, 1140.0,
#        775.0, 1515.0, 960.0, 1460.0, 13500.0, 1290.0, 1585.0, 1570.0,
#        2990.0, 1870.0, 1480.0, 1760.0, 3730.0, 6050.0, 1825.0, 4750.0,
#        3030.0, 1160.0, 1980.0, 3260.0, 4350.0, 3065.0, 910.0, 1299.0,
#        5100.0, 2570.0, 2690.0, 1385.0, 1185.0, 1395.0, 1695.0, 2720.0,
#        1435.0, 1565.0, 1360.0, 1345.0, 19000.0, 1940.0, 1625.0, 1180.0,
#        985.0, 1485.0, 1685.0, 915.0, 4620.0, 1890.0, 877.0, 1475.0,
#        5700.0, 1330.0, 4800.0, 1595.0, 17000.0, 2070.0, 1420.0, 4290.0,
#        1205.0, 1405.0, 1380.0, 1163.0, 1795.0, 2590.0, 2390.0, 1065.0,
#        770.0, 0.0, 810.0, 1410.0, 1285.0, 3650.0, 1520.0], dtype=object)

# %%
df_limpio
# Out:
#                                         id  \
# 0     d5c4c62a-f422-430a-bb28-ffd2003bde80
# 1     4447b365-9ad9-40e7-8a57-8019611cf4ce
# 2     2cd188dc-43db-4bb8-87ea-15e72ec27b60
# 3     1ccbb1b1-7a79-4c70-85f2-354dc10b354a
# 4     18c4c00d-98f9-40dd-be9e-3a012b63d9b1
# ...                                    ...
# 1980  d1f4cee2-dca3-4631-aa3b-d732d70e954d
# 1981  cb7da359-204c-415f-999a-75b979b35d61
# 1982  8e56eaf2-5c4c-426c-8501-e9114045f3e9
# 1983  882079aa-e895-4a7a-82eb-5736a3386069
# 1984  c67c8dd7-b917-45ac-9702-d3a3253fc725
#
#                                             Descripción  \
# 0                  Casa adosada en alquiler en Sector B
# 1             Piso en alquiler en Calle de Vista Alegre
# 2             Casa unifamiliar en alquiler en Calle XIX
# 3            Piso en alquiler en Zona Avenida de Europa
# 4                   Chalet en alquiler en Núcleo Urbano
# ...                                                 ...
# 1980    Apartamento en alquiler en Calle de Istúriz, 12
# 1981  Apartamento en alquiler en Avenida de Montes d...
# 1982               Piso en alquiler en Calle de Sagasta
# 1983   Loft en alquiler en Calle del Cerro del Murmullo
# 1984                           Piso en alquiler en Meco
#
#                                            Localización  \
# 0                         Sector B (Boadilla del Monte)
# 1     Somosaguas-Húmera-Los Ángeles (Pozuelo de Alar...
# 2        Las Matas-Los Peñascales (Las Rozas de Madrid)
# 3           Zona Avenida de Europa (Pozuelo de Alarcón)
# 4               Núcleo Urbano (Villanueva de la Cañada)
# ...                                                 ...
# 1980   Cuatro Caminos (Distrito Tetuán. Madrid Capital)
# 1981  Ciudalcampo-Fuente del Fresno (San Sebastián d...
# 1982  Justicia-Chueca (Distrito Centro. Madrid Capital)
# 1983  Ensanche de Vallecas-Valdecarros (Distrito Vil...
# 1984                                               Meco
#
#                                                  Enlace  Precio  \
# 0     https://www.pisos.com/alquilar/casa_adosada-se...  3600.0
# 1     https://www.pisos.com/alquilar/piso-somosaguas...  1450.0
# 2     https://www.pisos.com/alquilar/casa_unifamilia...  4000.0
# 3     https://www.pisos.com/alquilar/piso-zona_aveni...  1400.0
# 4     https://www.pisos.com/alquilar/chalet-villanue...  2700.0
# ...                                                 ...     ...
# 1980  https://www.pisos.com/alquilar/apartamento-tet...     0.0
# 1981  https://www.pisos.com/alquilar/apartamento-ciu...  1700.0
# 1982  https://www.pisos.com/alquilar/piso-justicia_c...  4100.0
# 1983  https://www.pisos.com/alquilar/loft-ensanche_d...   900.0
# 1984  https://www.pisos.com/alquilar/piso-meco_centr...   750.0
#
#      Última Actualización      Consumo Energético               Emisiones CO2  \
# 0              2024-10-21                     NaN                         NaN
# 1              2024-11-04                     NaN                         NaN
# 2              2024-11-04                     NaN                         NaN
# 3              2024-11-04                     NaN                         NaN
# 4              2024-10-28                     NaN                         NaN
# ...                   ...                     ...                         ...
# 1980           2024-06-06                     NaN                         NaN
# 1981           2024-11-04  Consumo:126 kWh/m² año  Emisiones:12 Kg CO₂/m² año
# 1982           2024-11-04                     NaN                         NaN
# 1983           2024-11-04                     NaN                         NaN
# 1984           2024-11-04                     NaN                         NaN
#
#      Tipo de operación           timestamp_scrapeo Superficie construida  \
# 0             Alquiler  2024-11-04T11:42:25.912524                448 m²
# 1             Alquiler  2024-11-04T11:42:34.398206                 69 m²
# 2             Alquiler  2024-11-04T11:42:40.242927                600 m²
# 3             Alquiler  2024-11-04T11:42:45.825335                 65 m²
# 4             Alquiler  2024-11-04T11:42:51.662813                329 m²
# ...                ...                         ...                   ...
# 1980          Alquiler  2024-11-04T15:35:33.283780                 70 m²
# 1981          Alquiler  2024-11-04T15:35:40.393501                101 m²
# 1982          Alquiler  2024-11-04T15:35:47.964623                110 m²
# 1983          Alquiler  2024-11-04T15:35:55.661331                 49 m²
# 1984          Alquiler  2024-11-04T15:36:02.652517                 47 m²
#
#      Habitaciones Baños          Antigüedad    Conservación Superficie útil  \
# 0               5     2     Menos de 5 años  En buen estado             NaN
# 1               1     1     Menos de 5 años  En buen estado           48 m²
# 2               6     7   Entre 5 y 10 años  En buen estado          600 m²
# 3               1     1                 NaN             NaN             NaN
# 4               5     3  Entre 20 y 30 años             NaN             NaN
# ...           ...   ...                 ...             ...             ...
# 1980            3     1      Más de 50 años      A estrenar           68 m²
# 1981            2     1     Menos de 5 años             NaN             NaN
# 1982            2     2  Entre 30 y 50 años       Reformado          100 m²
# 1983          NaN     1  Entre 10 y 20 años             NaN           30 m²
# 1984            1     1  Entre 20 y 30 años             NaN             NaN
#
#      Planta Tipo de Casa
# 0       NaN         Casa
# 1        1ª         Piso
# 2       NaN         Casa
# 3        2ª         Piso
# 4       NaN       Chalet
# ...     ...          ...
# 1980     2ª         Otro
# 1981    NaN         Otro
# 1982     3ª         Piso
# 1983   Bajo         Otro
# 1984     1ª         Piso
#
# [1985 rows x 18 columns]

# %%
# Rellenar valores nulos en columnas categóricas
df_limpio['Antigüedad'].fillna('No especificado', inplace=True)
df_limpio['Conservación'].fillna('No especificado', inplace=True)
df_limpio['Planta'].fillna('No especificado', inplace=True)
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_18524\911444348.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_limpio['Antigüedad'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_18524\911444348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Antigüedad'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_18524\911444348.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_limpio['Conservación'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_18524\911444348.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Conservación'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_18524\911444348.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_limpio['Planta'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_18524\911444348.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Planta'].fillna('No especificado', inplace=True)

# %%
 #Convertir 'Superficie construida' y 'Superficie útil' a numérico
df_limpio['Superficie construida'] = df_limpio['Superficie construida'].str.replace(' m²', '').astype(float)
df_limpio['Superficie útil'] = df_limpio['Superficie útil'].str.replace(' m²', '').astype(float)
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_18524\69539082.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Superficie construida'] = df_limpio['Superficie construida'].str.replace(' m²', '').astype(float)
# C:\Users\guill\AppData\Local\Temp\ipykernel_18524\69539082.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Superficie útil'] = df_limpio['Superficie útil'].str.replace(' m²', '').astype(float)

# %%
# Guardar el DataFrame limpio en un nuevo archivo CSV si deseas conservarlo
df_limpio.to_csv('inmuebles_alquiler_limpio.csv', index=False)

# Visualización del resultado
print(df_limpio.head())
# Out:
#                                      id  \
# 0  d5c4c62a-f422-430a-bb28-ffd2003bde80
# 1  4447b365-9ad9-40e7-8a57-8019611cf4ce
# 2  2cd188dc-43db-4bb8-87ea-15e72ec27b60
# 3  1ccbb1b1-7a79-4c70-85f2-354dc10b354a
# 4  18c4c00d-98f9-40dd-be9e-3a012b63d9b1
#
#                                   Descripción  \
# 0        Casa adosada en alquiler en Sector B
# 1   Piso en alquiler en Calle de Vista Alegre
# 2   Casa unifamiliar en alquiler en Calle XIX
# 3  Piso en alquiler en Zona Avenida de Europa
# 4         Chalet en alquiler en Núcleo Urbano
#
#                                         Localización  \
# 0                      Sector B (Boadilla del Monte)
# 1  Somosaguas-Húmera-Los Ángeles (Pozuelo de Alar...
# 2     Las Matas-Los Peñascales (Las Rozas de Madrid)
# 3        Zona Avenida de Europa (Pozuelo de Alarcón)
# 4            Núcleo Urbano (Villanueva de la Cañada)
#
#                                               Enlace  Precio  \
# 0  https://www.pisos.com/alquilar/casa_adosada-se...  3600.0
# 1  https://www.pisos.com/alquilar/piso-somosaguas...  1450.0
# 2  https://www.pisos.com/alquilar/casa_unifamilia...  4000.0
# 3  https://www.pisos.com/alquilar/piso-zona_aveni...  1400.0
# 4  https://www.pisos.com/alquilar/chalet-villanue...  2700.0
#
#   Última Actualización Consumo Energético Emisiones CO2 Tipo de operación  \
# 0           2024-10-21                NaN           NaN          Alquiler
# 1           2024-11-04                NaN           NaN          Alquiler
# 2           2024-11-04                NaN           NaN          Alquiler
# 3           2024-11-04                NaN           NaN          Alquiler
# 4           2024-10-28                NaN           NaN          Alquiler
#
#             timestamp_scrapeo  Superficie construida Habitaciones Baños  \
# 0  2024-11-04T11:42:25.912524                  448.0            5     2
# 1  2024-11-04T11:42:34.398206                   69.0            1     1
# 2  2024-11-04T11:42:40.242927                  600.0            6     7
# 3  2024-11-04T11:42:45.825335                   65.0            1     1
# 4  2024-11-04T11:42:51.662813                  329.0            5     3
#
#            Antigüedad     Conservación  Superficie útil           Planta  \
# 0     Menos de 5 años   En buen estado              NaN  No especificado
# 1     Menos de 5 años   En buen estado             48.0               1ª
# 2   Entre 5 y 10 años   En buen estado            600.0  No especificado
# 3     No especificado  No especificado              NaN               2ª
# 4  Entre 20 y 30 años  No especificado              NaN  No especificado
#
#   Tipo de Casa
# 0         Casa
# 1         Piso
# 2         Casa
# 3         Piso
# 4       Chalet
