# %%
# !pip install scipy
# !pip install seaborn
# !pip install matplotlib
# Out:
# Requirement already satisfied: scipy in c:\users\guill\proyecto\.venv\lib\site-packages (1.14.1)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\guill\proyecto\.venv\lib\site-packages (from scipy) (2.1.2)
# Requirement already satisfied: seaborn in c:\users\guill\proyecto\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\guill\proyecto\.venv\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\guill\proyecto\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\guill\proyecto\.venv\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\guill\proyecto\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\guill\proyecto\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\guill\proyecto\.venv\lib\site-packages (3.9.2)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\guill\proyecto\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\guill\proyecto\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from itertools import combinations
from scipy.stats import shapiro

# %%
alquiler = pd.read_csv("alquiler_inmuebles.csv")

# %%
df = alquiler.copy()

# %%
df
# Out:
#                                             Descripción  \
# 0             Casa unifamiliar en alquiler en Calle XIX
# 1            Piso en alquiler en Zona Avenida de Europa
# 2     Piso en alquiler en Calle Luis Garcia Cereceda...
# 3           Estudio en alquiler en Calle de Pollensa, 5
# 4     Piso en alquiler en Calle Gran Vía, cerca de C...
# ...                                                 ...
# 2114         Piso en alquiler en Calle de la Maquinilla
# 2115  Dúplex en alquiler en Avenida de Valdemarín, c...
# 2116                 Piso en alquiler en Cortes-Huertas
# 2117         Piso en alquiler en Calle de los Misterios
# 2118  Alquiler de pisos en Prosperidad, Distrito Cha...
#
#                                            Localización Precio  \
# 0        Las Matas-Los Peñascales (Las Rozas de Madrid)  4.000
# 1           Zona Avenida de Europa (Pozuelo de Alarcón)  1.400
# 2                         La Finca (Pozuelo de Alarcón)  5.500
# 3              Parque Empresarial (Las Rozas de Madrid)  1.147
# 4     Universidad-Malasaña (Distrito Centro. Madrid ...  3.500
# ...                                                 ...    ...
# 2114               ¡Vaya! Esta propiedad no tiene fotos    950
# 2115  Valdemarín (Distrito Moncloa-Aravaca. Madrid C...  3.900
# 2116   Cortes-Huertas (Distrito Centro. Madrid Capital)  1.200
# 2117  Quintana (Distrito Ciudad Lineal. Madrid Capital)    950
# 2118                         Sé el primero en enterarte    NaN
#
#      Superficie Construida               Última Actualización  \
# 0                      600  Anuncio actualizado el 28/10/2024
# 1                       65  Anuncio actualizado el 28/10/2024
# 2                      190  Anuncio actualizado el 28/10/2024
# 3                       50  Anuncio actualizado el 03/07/2024
# 4                      122  Anuncio actualizado el 03/10/2024
# ...                    ...                                ...
# 2114                    45  Anuncio actualizado el 28/10/2024
# 2115                   220  Anuncio actualizado el 28/10/2024
# 2116                    52  Anuncio actualizado el 28/10/2024
# 2117                    38  Anuncio actualizado el 28/10/2024
# 2118                   NaN                                NaN
#
#           Consumo Energético                Emisiones CO2  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2      Consumo:15 kWh/m² año    Emisiones:2 Kg CO₂/m² año
# 3                        NaN                          NaN
# 4      Consumo:70 kWh/m² año   Emisiones:15 Kg CO₂/m² año
# ...                      ...                          ...
# 2114   Consumo:30 kWh/m² año  Emisiones:179 Kg CO₂/m² año
# 2115                     NaN                          NaN
# 2116  Consumo:190 kWh/m² año   Emisiones:32 Kg CO₂/m² año
# 2117                     NaN                          NaN
# 2118                     NaN                          NaN
#
#                                         Características Tipo de operación
# 0     [('Superficie construida:', '600 m²'), ('Super...          Alquiler
# 1     [('Superficie construida:', '65 m²'), ('Habita...          Alquiler
# 2     [('Superficie construida:', '190 m²'), ('Super...          Alquiler
# 3     [('Superficie construida:', '50 m²'), ('Baños:...          Alquiler
# 4     [('Superficie construida:', '122 m²'), ('Super...          Alquiler
# ...                                                 ...               ...
# 2114  [('Superficie construida:', '45 m²'), ('Habita...          Alquiler
# 2115  [('Superficie construida:', '220 m²'), ('Super...          Alquiler
# 2116  [('Superficie construida:', '52 m²'), ('Habita...          Alquiler
# 2117  [('Superficie construida:', '38 m²'), ('Superf...          Alquiler
# 2118                                                NaN          Alquiler
#
# [2119 rows x 9 columns]

# %%
df.head()
# Out:
#                                          Descripción  \
# 0          Casa unifamiliar en alquiler en Calle XIX
# 1         Piso en alquiler en Zona Avenida de Europa
# 2  Piso en alquiler en Calle Luis Garcia Cereceda...
# 3        Estudio en alquiler en Calle de Pollensa, 5
# 4  Piso en alquiler en Calle Gran Vía, cerca de C...
#
#                                         Localización Precio  \
# 0     Las Matas-Los Peñascales (Las Rozas de Madrid)  4.000
# 1        Zona Avenida de Europa (Pozuelo de Alarcón)  1.400
# 2                      La Finca (Pozuelo de Alarcón)  5.500
# 3           Parque Empresarial (Las Rozas de Madrid)  1.147
# 4  Universidad-Malasaña (Distrito Centro. Madrid ...  3.500
#
#   Superficie Construida               Última Actualización  \
# 0                   600  Anuncio actualizado el 28/10/2024
# 1                    65  Anuncio actualizado el 28/10/2024
# 2                   190  Anuncio actualizado el 28/10/2024
# 3                    50  Anuncio actualizado el 03/07/2024
# 4                   122  Anuncio actualizado el 03/10/2024
#
#       Consumo Energético               Emisiones CO2  \
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2  Consumo:15 kWh/m² año   Emisiones:2 Kg CO₂/m² año
# 3                    NaN                         NaN
# 4  Consumo:70 kWh/m² año  Emisiones:15 Kg CO₂/m² año
#
#                                      Características Tipo de operación
# 0  [('Superficie construida:', '600 m²'), ('Super...          Alquiler
# 1  [('Superficie construida:', '65 m²'), ('Habita...          Alquiler
# 2  [('Superficie construida:', '190 m²'), ('Super...          Alquiler
# 3  [('Superficie construida:', '50 m²'), ('Baños:...          Alquiler
# 4  [('Superficie construida:', '122 m²'), ('Super...          Alquiler

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2119 entries, 0 to 2118
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Descripción            2119 non-null   object
#  1   Localización           2119 non-null   object
#  2   Precio                 2118 non-null   object
#  3   Superficie Construida  2118 non-null   object
#  4   Última Actualización   2118 non-null   object
#  5   Consumo Energético     553 non-null    object
#  6   Emisiones CO2          553 non-null    object
#  7   Características        2118 non-null   object
#  8   Tipo de operación      2119 non-null   object
# dtypes: object(9)
# memory usage: 149.1+ KB

# %%
 #muchos nulos en consumo y emisiones

# %%
# Función para extraer las características de la columna y convertirlas en columnas separadas
def extraer_caracteristicas(fila):
    # Elimina los caracteres adicionales para convertir la cadena en una lista de tuplas
    fila = fila.strip("[]")  # Elimina los corchetes externos
    elementos = fila.split("), (")  # Divide la cadena en tuplas individuales
    
    datos_extraidos = {}
    for elemento in elementos:
        # Divide cada elemento en clave y valor
        clave, valor = elemento.split(", ", 1)
        clave = clave.replace("(", "").replace("'", "").strip()  # Limpia clave
        valor = valor.replace(")", "").replace("'", "").strip()  # Limpia valor
        datos_extraidos[clave.strip(':')] = valor  # Remueve ':' del final de la clave si está presente
    return datos_extraidos

# Aplicar la función a la columna 'Características' y expandir en columnas separadas
caracteristicas_df = df['Características'].dropna().apply(extraer_caracteristicas)
caracteristicas_expandidas = pd.json_normalize(caracteristicas_df)

# Combinar las columnas expandidas con el DataFrame original (elimina la columna 'Características' original)
df_limpio = pd.concat([df.drop(columns=['Características']), caracteristicas_expandidas], axis=1)

# Guardar el DataFrame limpio en un nuevo archivo CSV si deseas conservarlo
df_limpio.to_csv('alquiler_inmuebles_limpio.csv', index=False)

# Visualización del resultado
print(df_limpio.head())
# Out:
#                                          Descripción  \
# 0          Casa unifamiliar en alquiler en Calle XIX
# 1         Piso en alquiler en Zona Avenida de Europa
# 2  Piso en alquiler en Calle Luis Garcia Cereceda...
# 3        Estudio en alquiler en Calle de Pollensa, 5
# 4  Piso en alquiler en Calle Gran Vía, cerca de C...
#
#                                         Localización Precio  \
# 0     Las Matas-Los Peñascales (Las Rozas de Madrid)  4.000
# 1        Zona Avenida de Europa (Pozuelo de Alarcón)  1.400
# 2                      La Finca (Pozuelo de Alarcón)  5.500
# 3           Parque Empresarial (Las Rozas de Madrid)  1.147
# 4  Universidad-Malasaña (Distrito Centro. Madrid ...  3.500
#
#   Superficie Construida               Última Actualización  \
# 0                   600  Anuncio actualizado el 28/10/2024
# 1                    65  Anuncio actualizado el 28/10/2024
# 2                   190  Anuncio actualizado el 28/10/2024
# 3                    50  Anuncio actualizado el 03/07/2024
# 4                   122  Anuncio actualizado el 03/10/2024
#
#       Consumo Energético               Emisiones CO2 Tipo de operación  \
# 0                    NaN                         NaN          Alquiler
# 1                    NaN                         NaN          Alquiler
# 2  Consumo:15 kWh/m² año   Emisiones:2 Kg CO₂/m² año          Alquiler
# 3                    NaN                         NaN          Alquiler
# 4  Consumo:70 kWh/m² año  Emisiones:15 Kg CO₂/m² año          Alquiler
#
#   Superficie construida Superficie útil  ... Baños Tipo de casa  \
# 0                600 m²          600 m²  ...     7  Unifamiliar
# 1                 65 m²             NaN  ...     1          NaN
# 2                190 m²          170 m²  ...     3          NaN
# 3                 50 m²             NaN  ...     1          NaN
# 4                122 m²          120 m²  ...     2          NaN
#
#           Antigüedad    Conservación              Referencia Planta  \
# 0  Entre 5 y 10 años  En buen estado             2805-002317    NaN
# 1                NaN             NaN  IF5032-avda-1d-V T 40m     2ª
# 2    Menos de 5 años  En buen estado             2805-002404     2ª
# 3                NaN             NaN         IF5032-tartesos    NaN
# 4  Entre 5 y 10 años       Reformado          4528417-000005     8ª
#
#   Gastos de comunidad Superficie solar Exterior Interior
# 0                 NaN              NaN      NaN      NaN
# 1                 NaN              NaN      NaN      NaN
# 2           Incluidos              NaN      NaN      NaN
# 3                 NaN              NaN      NaN      NaN
# 4                 NaN              NaN      NaN      NaN
#
# [5 rows x 21 columns]

# %%
df_limpio
# Out:
#                                             Descripción  \
# 0             Casa unifamiliar en alquiler en Calle XIX
# 1            Piso en alquiler en Zona Avenida de Europa
# 2     Piso en alquiler en Calle Luis Garcia Cereceda...
# 3           Estudio en alquiler en Calle de Pollensa, 5
# 4     Piso en alquiler en Calle Gran Vía, cerca de C...
# ...                                                 ...
# 2114         Piso en alquiler en Calle de la Maquinilla
# 2115  Dúplex en alquiler en Avenida de Valdemarín, c...
# 2116                 Piso en alquiler en Cortes-Huertas
# 2117         Piso en alquiler en Calle de los Misterios
# 2118  Alquiler de pisos en Prosperidad, Distrito Cha...
#
#                                            Localización Precio  \
# 0        Las Matas-Los Peñascales (Las Rozas de Madrid)  4.000
# 1           Zona Avenida de Europa (Pozuelo de Alarcón)  1.400
# 2                         La Finca (Pozuelo de Alarcón)  5.500
# 3              Parque Empresarial (Las Rozas de Madrid)  1.147
# 4     Universidad-Malasaña (Distrito Centro. Madrid ...  3.500
# ...                                                 ...    ...
# 2114               ¡Vaya! Esta propiedad no tiene fotos    950
# 2115  Valdemarín (Distrito Moncloa-Aravaca. Madrid C...  3.900
# 2116   Cortes-Huertas (Distrito Centro. Madrid Capital)  1.200
# 2117  Quintana (Distrito Ciudad Lineal. Madrid Capital)    950
# 2118                         Sé el primero en enterarte    NaN
#
#      Superficie Construida               Última Actualización  \
# 0                      600  Anuncio actualizado el 28/10/2024
# 1                       65  Anuncio actualizado el 28/10/2024
# 2                      190  Anuncio actualizado el 28/10/2024
# 3                       50  Anuncio actualizado el 03/07/2024
# 4                      122  Anuncio actualizado el 03/10/2024
# ...                    ...                                ...
# 2114                    45  Anuncio actualizado el 28/10/2024
# 2115                   220  Anuncio actualizado el 28/10/2024
# 2116                    52  Anuncio actualizado el 28/10/2024
# 2117                    38  Anuncio actualizado el 28/10/2024
# 2118                   NaN                                NaN
#
#           Consumo Energético                Emisiones CO2 Tipo de operación  \
# 0                        NaN                          NaN          Alquiler
# 1                        NaN                          NaN          Alquiler
# 2      Consumo:15 kWh/m² año    Emisiones:2 Kg CO₂/m² año          Alquiler
# 3                        NaN                          NaN          Alquiler
# 4      Consumo:70 kWh/m² año   Emisiones:15 Kg CO₂/m² año          Alquiler
# ...                      ...                          ...               ...
# 2114   Consumo:30 kWh/m² año  Emisiones:179 Kg CO₂/m² año          Alquiler
# 2115                     NaN                          NaN          Alquiler
# 2116  Consumo:190 kWh/m² año   Emisiones:32 Kg CO₂/m² año          Alquiler
# 2117                     NaN                          NaN          Alquiler
# 2118                     NaN                          NaN          Alquiler
#
#      Superficie construida Superficie útil  ... Baños Tipo de casa  \
# 0                   600 m²          600 m²  ...     7  Unifamiliar
# 1                    65 m²             NaN  ...     1          NaN
# 2                   190 m²          170 m²  ...     3          NaN
# 3                    50 m²             NaN  ...     1          NaN
# 4                   122 m²          120 m²  ...     2          NaN
# ...                    ...             ...  ...   ...          ...
# 2114                 45 m²             NaN  ...     1          NaN
# 2115                220 m²          170 m²  ...     4          NaN
# 2116                 52 m²             NaN  ...     1          NaN
# 2117                 38 m²           30 m²  ...   NaN          NaN
# 2118                   NaN             NaN  ...   NaN          NaN
#
#               Antigüedad    Conservación              Referencia Planta  \
# 0      Entre 5 y 10 años  En buen estado             2805-002317    NaN
# 1                    NaN             NaN  IF5032-avda-1d-V T 40m     2ª
# 2        Menos de 5 años  En buen estado             2805-002404     2ª
# 3                    NaN             NaN         IF5032-tartesos    NaN
# 4      Entre 5 y 10 años       Reformado          4528417-000005     8ª
# ...                  ...             ...                     ...    ...
# 2114                 NaN  En buen estado        SA3739-106396052     3ª
# 2115  Entre 20 y 30 años  En buen estado       SA2484-3248-24157     2ª
# 2116      Más de 50 años  En buen estado           TC1114-599437     2ª
# 2117                 NaN             NaN              XA614-1674     2ª
# 2118                 NaN             NaN                     NaN    NaN
#
#      Gastos de comunidad Superficie solar Exterior Interior
# 0                    NaN              NaN      NaN      NaN
# 1                    NaN              NaN      NaN      NaN
# 2              Incluidos              NaN      NaN      NaN
# 3                    NaN              NaN      NaN      NaN
# 4                    NaN              NaN      NaN      NaN
# ...                  ...              ...      ...      ...
# 2114                 NaN              NaN      NaN      NaN
# 2115                 NaN              NaN      NaN      NaN
# 2116                 NaN              NaN      NaN      NaN
# 2117                 NaN              NaN      NaN      NaN
# 2118                 NaN              NaN      NaN      NaN
#
# [2119 rows x 21 columns]

# %%
# Lista de tipos de casa que queremos identificar
tipos_casa = ["Piso", "Chalet", "Adosado", "Casa", "Estudio", "Dúplex"]

# Función para extraer el tipo de casa de la descripción
def extraer_tipo_casa(descripcion):
    for tipo in tipos_casa:
        if tipo.lower() in descripcion.lower():
            return tipo
    return "Otro"  # Valor por defecto si no coincide con ninguno de los tipos en la lista

# Crear una nueva columna en el DataFrame con el tipo de casa
df_limpio['Tipo de Casa'] = df_limpio['Descripción'].apply(extraer_tipo_casa)

# Visualización del resultado
print(df_limpio[['Descripción', 'Tipo de Casa']].head())
# Out:
#                                          Descripción Tipo de Casa
# 0          Casa unifamiliar en alquiler en Calle XIX         Casa
# 1         Piso en alquiler en Zona Avenida de Europa         Piso
# 2  Piso en alquiler en Calle Luis Garcia Cereceda...         Piso
# 3        Estudio en alquiler en Calle de Pollensa, 5      Estudio
# 4  Piso en alquiler en Calle Gran Vía, cerca de C...         Piso

# %%
df_limpio
# Out:
#                                             Descripción  \
# 0             Casa unifamiliar en alquiler en Calle XIX
# 1            Piso en alquiler en Zona Avenida de Europa
# 2     Piso en alquiler en Calle Luis Garcia Cereceda...
# 3           Estudio en alquiler en Calle de Pollensa, 5
# 4     Piso en alquiler en Calle Gran Vía, cerca de C...
# ...                                                 ...
# 2114         Piso en alquiler en Calle de la Maquinilla
# 2115  Dúplex en alquiler en Avenida de Valdemarín, c...
# 2116                 Piso en alquiler en Cortes-Huertas
# 2117         Piso en alquiler en Calle de los Misterios
# 2118  Alquiler de pisos en Prosperidad, Distrito Cha...
#
#                                            Localización Precio  \
# 0        Las Matas-Los Peñascales (Las Rozas de Madrid)  4.000
# 1           Zona Avenida de Europa (Pozuelo de Alarcón)  1.400
# 2                         La Finca (Pozuelo de Alarcón)  5.500
# 3              Parque Empresarial (Las Rozas de Madrid)  1.147
# 4     Universidad-Malasaña (Distrito Centro. Madrid ...  3.500
# ...                                                 ...    ...
# 2114               ¡Vaya! Esta propiedad no tiene fotos    950
# 2115  Valdemarín (Distrito Moncloa-Aravaca. Madrid C...  3.900
# 2116   Cortes-Huertas (Distrito Centro. Madrid Capital)  1.200
# 2117  Quintana (Distrito Ciudad Lineal. Madrid Capital)    950
# 2118                         Sé el primero en enterarte    NaN
#
#      Superficie Construida               Última Actualización  \
# 0                      600  Anuncio actualizado el 28/10/2024
# 1                       65  Anuncio actualizado el 28/10/2024
# 2                      190  Anuncio actualizado el 28/10/2024
# 3                       50  Anuncio actualizado el 03/07/2024
# 4                      122  Anuncio actualizado el 03/10/2024
# ...                    ...                                ...
# 2114                    45  Anuncio actualizado el 28/10/2024
# 2115                   220  Anuncio actualizado el 28/10/2024
# 2116                    52  Anuncio actualizado el 28/10/2024
# 2117                    38  Anuncio actualizado el 28/10/2024
# 2118                   NaN                                NaN
#
#           Consumo Energético                Emisiones CO2 Tipo de operación  \
# 0                        NaN                          NaN          Alquiler
# 1                        NaN                          NaN          Alquiler
# 2      Consumo:15 kWh/m² año    Emisiones:2 Kg CO₂/m² año          Alquiler
# 3                        NaN                          NaN          Alquiler
# 4      Consumo:70 kWh/m² año   Emisiones:15 Kg CO₂/m² año          Alquiler
# ...                      ...                          ...               ...
# 2114   Consumo:30 kWh/m² año  Emisiones:179 Kg CO₂/m² año          Alquiler
# 2115                     NaN                          NaN          Alquiler
# 2116  Consumo:190 kWh/m² año   Emisiones:32 Kg CO₂/m² año          Alquiler
# 2117                     NaN                          NaN          Alquiler
# 2118                     NaN                          NaN          Alquiler
#
#      Superficie construida Superficie útil  ... Tipo de casa  \
# 0                   600 m²          600 m²  ...  Unifamiliar
# 1                    65 m²             NaN  ...          NaN
# 2                   190 m²          170 m²  ...          NaN
# 3                    50 m²             NaN  ...          NaN
# 4                   122 m²          120 m²  ...          NaN
# ...                    ...             ...  ...          ...
# 2114                 45 m²             NaN  ...          NaN
# 2115                220 m²          170 m²  ...          NaN
# 2116                 52 m²             NaN  ...          NaN
# 2117                 38 m²           30 m²  ...          NaN
# 2118                   NaN             NaN  ...          NaN
#
#               Antigüedad    Conservación              Referencia Planta  \
# 0      Entre 5 y 10 años  En buen estado             2805-002317    NaN
# 1                    NaN             NaN  IF5032-avda-1d-V T 40m     2ª
# 2        Menos de 5 años  En buen estado             2805-002404     2ª
# 3                    NaN             NaN         IF5032-tartesos    NaN
# 4      Entre 5 y 10 años       Reformado          4528417-000005     8ª
# ...                  ...             ...                     ...    ...
# 2114                 NaN  En buen estado        SA3739-106396052     3ª
# 2115  Entre 20 y 30 años  En buen estado       SA2484-3248-24157     2ª
# 2116      Más de 50 años  En buen estado           TC1114-599437     2ª
# 2117                 NaN             NaN              XA614-1674     2ª
# 2118                 NaN             NaN                     NaN    NaN
#
#      Gastos de comunidad Superficie solar Exterior Interior Tipo de Casa
# 0                    NaN              NaN      NaN      NaN         Casa
# 1                    NaN              NaN      NaN      NaN         Piso
# 2              Incluidos              NaN      NaN      NaN         Piso
# 3                    NaN              NaN      NaN      NaN      Estudio
# 4                    NaN              NaN      NaN      NaN         Piso
# ...                  ...              ...      ...      ...          ...
# 2114                 NaN              NaN      NaN      NaN         Piso
# 2115                 NaN              NaN      NaN      NaN       Dúplex
# 2116                 NaN              NaN      NaN      NaN         Piso
# 2117                 NaN              NaN      NaN      NaN         Piso
# 2118                 NaN              NaN      NaN      NaN         Piso
#
# [2119 rows x 22 columns]

# %%
df_limpio = df_limpio.drop(columns=["Superficie Construida","Tipo de casa","Referencia","Gastos de comunidad","Superficie solar","Interior","Exterior"])

# %%
df_limpio
# Out:
#                                             Descripción  \
# 0             Casa unifamiliar en alquiler en Calle XIX
# 1            Piso en alquiler en Zona Avenida de Europa
# 2     Piso en alquiler en Calle Luis Garcia Cereceda...
# 3           Estudio en alquiler en Calle de Pollensa, 5
# 4     Piso en alquiler en Calle Gran Vía, cerca de C...
# ...                                                 ...
# 2114         Piso en alquiler en Calle de la Maquinilla
# 2115  Dúplex en alquiler en Avenida de Valdemarín, c...
# 2116                 Piso en alquiler en Cortes-Huertas
# 2117         Piso en alquiler en Calle de los Misterios
# 2118  Alquiler de pisos en Prosperidad, Distrito Cha...
#
#                                            Localización Precio  \
# 0        Las Matas-Los Peñascales (Las Rozas de Madrid)  4.000
# 1           Zona Avenida de Europa (Pozuelo de Alarcón)  1.400
# 2                         La Finca (Pozuelo de Alarcón)  5.500
# 3              Parque Empresarial (Las Rozas de Madrid)  1.147
# 4     Universidad-Malasaña (Distrito Centro. Madrid ...  3.500
# ...                                                 ...    ...
# 2114               ¡Vaya! Esta propiedad no tiene fotos    950
# 2115  Valdemarín (Distrito Moncloa-Aravaca. Madrid C...  3.900
# 2116   Cortes-Huertas (Distrito Centro. Madrid Capital)  1.200
# 2117  Quintana (Distrito Ciudad Lineal. Madrid Capital)    950
# 2118                         Sé el primero en enterarte    NaN
#
#                    Última Actualización      Consumo Energético  \
# 0     Anuncio actualizado el 28/10/2024                     NaN
# 1     Anuncio actualizado el 28/10/2024                     NaN
# 2     Anuncio actualizado el 28/10/2024   Consumo:15 kWh/m² año
# 3     Anuncio actualizado el 03/07/2024                     NaN
# 4     Anuncio actualizado el 03/10/2024   Consumo:70 kWh/m² año
# ...                                 ...                     ...
# 2114  Anuncio actualizado el 28/10/2024   Consumo:30 kWh/m² año
# 2115  Anuncio actualizado el 28/10/2024                     NaN
# 2116  Anuncio actualizado el 28/10/2024  Consumo:190 kWh/m² año
# 2117  Anuncio actualizado el 28/10/2024                     NaN
# 2118                                NaN                     NaN
#
#                     Emisiones CO2 Tipo de operación Superficie construida  \
# 0                             NaN          Alquiler                600 m²
# 1                             NaN          Alquiler                 65 m²
# 2       Emisiones:2 Kg CO₂/m² año          Alquiler                190 m²
# 3                             NaN          Alquiler                 50 m²
# 4      Emisiones:15 Kg CO₂/m² año          Alquiler                122 m²
# ...                           ...               ...                   ...
# 2114  Emisiones:179 Kg CO₂/m² año          Alquiler                 45 m²
# 2115                          NaN          Alquiler                220 m²
# 2116   Emisiones:32 Kg CO₂/m² año          Alquiler                 52 m²
# 2117                          NaN          Alquiler                 38 m²
# 2118                          NaN          Alquiler                   NaN
#
#      Superficie útil Habitaciones Baños          Antigüedad    Conservación  \
# 0             600 m²            6     7   Entre 5 y 10 años  En buen estado
# 1                NaN            1     1                 NaN             NaN
# 2             170 m²            3     3     Menos de 5 años  En buen estado
# 3                NaN          NaN     1                 NaN             NaN
# 4             120 m²            2     2   Entre 5 y 10 años       Reformado
# ...              ...          ...   ...                 ...             ...
# 2114             NaN            1     1                 NaN  En buen estado
# 2115          170 m²            4     4  Entre 20 y 30 años  En buen estado
# 2116             NaN            2     1      Más de 50 años  En buen estado
# 2117           30 m²          NaN   NaN                 NaN             NaN
# 2118             NaN          NaN   NaN                 NaN             NaN
#
#      Planta Tipo de Casa
# 0       NaN         Casa
# 1        2ª         Piso
# 2        2ª         Piso
# 3       NaN      Estudio
# 4        8ª         Piso
# ...     ...          ...
# 2114     3ª         Piso
# 2115     2ª       Dúplex
# 2116     2ª         Piso
# 2117     2ª         Piso
# 2118    NaN         Piso
#
# [2119 rows x 15 columns]

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2119 entries, 0 to 2118
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Descripción            2119 non-null   object
#  1   Localización           2119 non-null   object
#  2   Precio                 2118 non-null   object
#  3   Última Actualización   2118 non-null   object
#  4   Consumo Energético     553 non-null    object
#  5   Emisiones CO2          553 non-null    object
#  6   Tipo de operación      2119 non-null   object
#  7   Superficie construida  2110 non-null   object
#  8   Superficie útil        791 non-null    object
#  9   Habitaciones           2039 non-null   object
#  10  Baños                  2056 non-null   object
#  11  Antigüedad             898 non-null    object
#  12  Conservación           1352 non-null   object
#  13  Planta                 1537 non-null   object
#  14  Tipo de Casa           2119 non-null   object
# dtypes: object(15)
# memory usage: 248.4+ KB

# %%
# Extraer la fecha de la columna 'Última Actualización' y convertirla a tipo datetime
df_limpio['Última Actualización'] = df_limpio['Última Actualización'].str.extract(r'(\d{2}/\d{2}/\d{4})')
df_limpio['Última Actualización'] = pd.to_datetime(df_limpio['Última Actualización'], format='%d/%m/%Y')

# Verificar el resultado
print(df_limpio['Última Actualización'].head())
# Out:
# 0   2024-10-28
# 1   2024-10-28
# 2   2024-10-28
# 3   2024-07-03
# 4   2024-10-03
# Name: Última Actualización, dtype: datetime64[ns]

# %%
df_limpio
# Out:
#                                             Descripción  \
# 0             Casa unifamiliar en alquiler en Calle XIX
# 1            Piso en alquiler en Zona Avenida de Europa
# 2     Piso en alquiler en Calle Luis Garcia Cereceda...
# 3           Estudio en alquiler en Calle de Pollensa, 5
# 4     Piso en alquiler en Calle Gran Vía, cerca de C...
# ...                                                 ...
# 2114         Piso en alquiler en Calle de la Maquinilla
# 2115  Dúplex en alquiler en Avenida de Valdemarín, c...
# 2116                 Piso en alquiler en Cortes-Huertas
# 2117         Piso en alquiler en Calle de los Misterios
# 2118  Alquiler de pisos en Prosperidad, Distrito Cha...
#
#                                            Localización Precio  \
# 0        Las Matas-Los Peñascales (Las Rozas de Madrid)  4.000
# 1           Zona Avenida de Europa (Pozuelo de Alarcón)  1.400
# 2                         La Finca (Pozuelo de Alarcón)  5.500
# 3              Parque Empresarial (Las Rozas de Madrid)  1.147
# 4     Universidad-Malasaña (Distrito Centro. Madrid ...  3.500
# ...                                                 ...    ...
# 2114               ¡Vaya! Esta propiedad no tiene fotos    950
# 2115  Valdemarín (Distrito Moncloa-Aravaca. Madrid C...  3.900
# 2116   Cortes-Huertas (Distrito Centro. Madrid Capital)  1.200
# 2117  Quintana (Distrito Ciudad Lineal. Madrid Capital)    950
# 2118                         Sé el primero en enterarte    NaN
#
#      Última Actualización      Consumo Energético  \
# 0              2024-10-28                     NaN
# 1              2024-10-28                     NaN
# 2              2024-10-28   Consumo:15 kWh/m² año
# 3              2024-07-03                     NaN
# 4              2024-10-03   Consumo:70 kWh/m² año
# ...                   ...                     ...
# 2114           2024-10-28   Consumo:30 kWh/m² año
# 2115           2024-10-28                     NaN
# 2116           2024-10-28  Consumo:190 kWh/m² año
# 2117           2024-10-28                     NaN
# 2118                  NaT                     NaN
#
#                     Emisiones CO2 Tipo de operación Superficie construida  \
# 0                             NaN          Alquiler                600 m²
# 1                             NaN          Alquiler                 65 m²
# 2       Emisiones:2 Kg CO₂/m² año          Alquiler                190 m²
# 3                             NaN          Alquiler                 50 m²
# 4      Emisiones:15 Kg CO₂/m² año          Alquiler                122 m²
# ...                           ...               ...                   ...
# 2114  Emisiones:179 Kg CO₂/m² año          Alquiler                 45 m²
# 2115                          NaN          Alquiler                220 m²
# 2116   Emisiones:32 Kg CO₂/m² año          Alquiler                 52 m²
# 2117                          NaN          Alquiler                 38 m²
# 2118                          NaN          Alquiler                   NaN
#
#      Superficie útil Habitaciones Baños          Antigüedad    Conservación  \
# 0             600 m²            6     7   Entre 5 y 10 años  En buen estado
# 1                NaN            1     1                 NaN             NaN
# 2             170 m²            3     3     Menos de 5 años  En buen estado
# 3                NaN          NaN     1                 NaN             NaN
# 4             120 m²            2     2   Entre 5 y 10 años       Reformado
# ...              ...          ...   ...                 ...             ...
# 2114             NaN            1     1                 NaN  En buen estado
# 2115          170 m²            4     4  Entre 20 y 30 años  En buen estado
# 2116             NaN            2     1      Más de 50 años  En buen estado
# 2117           30 m²          NaN   NaN                 NaN             NaN
# 2118             NaN          NaN   NaN                 NaN             NaN
#
#      Planta Tipo de Casa
# 0       NaN         Casa
# 1        2ª         Piso
# 2        2ª         Piso
# 3       NaN      Estudio
# 4        8ª         Piso
# ...     ...          ...
# 2114     3ª         Piso
# 2115     2ª       Dúplex
# 2116     2ª         Piso
# 2117     2ª         Piso
# 2118    NaN         Piso
#
# [2119 rows x 15 columns]

# %%
# Eliminar filas donde 'Precio' es NaN
df_limpio = df_limpio.dropna(subset=['Precio'])

# %%
# Filtrar filas en 'Precio' que contienen caracteres no numéricos
valores_no_numericos = df_limpio[~df_limpio['Precio'].str.replace('.', '', regex=False).str.replace(',', '', regex=False).str.isnumeric()]

# Mostrar los resultados
print(valores_no_numericos[['Precio']])
# Out:
#      Precio
# 626       A
# 661       A
# 801       A
# 2029      A
# 2051      A
# 2061      A
# 2062      A
# 2063      A
# 2108      A
# 2111      A

# %%
# Mostrar filas en los índices específicos
indices_a = [626, 661, 801, 2029, 2051, 2061, 2062, 2063, 2108, 2111]
print(df.loc[indices_a])
# Out:
#                                             Descripción  \
# 626        Piso en alquiler en Calle de Rafael Bergamín
# 661       Piso en alquiler en Plaza de la Independencia
# 801   Piso en alquiler en Calle de Alcalá, cerca de ...
# 2029  Casa en alquiler en Ciudalcampo-Fuente del Fresno
# 2051                  Piso en alquiler en Ciudad Lineal
# 2061             Piso en alquiler en Puente de Vallecas
# 2062             Apartamento en alquiler en Almendrales
# 2063                       Piso en alquiler en Vallecas
# 2108  Piso en alquiler en Calle de Casado del Alisal...
# 2111    Apartamento en alquiler en Calle de Istúriz, 12
#
#                                            Localización Precio  \
# 626   San Juan Bautista (Distrito Ciudad Lineal. Mad...      A
# 661      Recoletos (Distrito Salamanca. Madrid Capital)      A
# 801         Jerónimos (Distrito Retiro. Madrid Capital)      A
# 2029  Ciudalcampo-Fuente del Fresno (San Sebastián d...      A
# 2051               ¡Vaya! Esta propiedad no tiene fotos      A
# 2061               ¡Vaya! Esta propiedad no tiene fotos      A
# 2062               ¡Vaya! Esta propiedad no tiene fotos      A
# 2063               ¡Vaya! Esta propiedad no tiene fotos      A
# 2108        Jerónimos (Distrito Retiro. Madrid Capital)      A
# 2111   Cuatro Caminos (Distrito Tetuán. Madrid Capital)      A
#
#      Superficie Construida               Última Actualización  \
# 626                     95  Anuncio actualizado el 28/10/2024
# 661                    492  Anuncio actualizado el 20/10/2024
# 801                    492  Anuncio actualizado el 23/10/2024
# 2029                   960  Anuncio actualizado el 14/08/2024
# 2051                  Bajo  Anuncio actualizado el 09/10/2024
# 2061                  Bajo  Anuncio actualizado el 18/09/2024
# 2062                  Bajo  Anuncio actualizado el 04/09/2024
# 2063                  Bajo  Anuncio actualizado el 26/09/2024
# 2108                   144  Anuncio actualizado el 04/10/2024
# 2111                    70  Anuncio actualizado el 06/06/2024
#
#      Consumo Energético Emisiones CO2  \
# 626                 NaN           NaN
# 661                 NaN           NaN
# 801                 NaN           NaN
# 2029                NaN           NaN
# 2051                NaN           NaN
# 2061                NaN           NaN
# 2062                NaN           NaN
# 2063                NaN           NaN
# 2108                NaN           NaN
# 2111                NaN           NaN
#
#                                         Características Tipo de operación
# 626   [('Superficie construida:', '95 m²'), ('Superf...          Alquiler
# 661   [('Superficie construida:', '492 m²'), ('Habit...          Alquiler
# 801   [('Superficie construida:', '492 m²'), ('Habit...          Alquiler
# 2029  [('Superficie construida:', '960 m²'), ('Super...          Alquiler
# 2051  [('Planta:', 'Bajo'), ('Referencia:', 'SA4312-...          Alquiler
# 2061  [('Planta:', 'Bajo'), ('Antigüedad:', 'Más de ...          Alquiler
# 2062  [('Planta:', 'Bajo'), ('Referencia:', 'SA4312-...          Alquiler
# 2063  [('Planta:', 'Bajo'), ('Referencia:', 'SA4312-...          Alquiler
# 2108  [('Superficie construida:', '144 m²'), ('Super...          Alquiler
# 2111  [('Superficie construida:', '70 m²'), ('Superf...          Alquiler

# %%
# Usar .loc para evitar el SettingWithCopyWarning
df_limpio.loc[df_limpio['Precio'] == 'A', 'Precio'] = 0

# %%
# Limpiar valores en la columna 'Precio', eliminando puntos y comas, y convertir a float
df_limpio.loc[:, 'Precio'] = df_limpio['Precio'].replace({r'\.': '', ',': ''}, regex=True).astype(float)

# %%
df_limpio["Precio"].unique()
# Out:
# array([ 4000.,  1400.,  5500.,  1147.,  3500.,  3750.,  1450.,  3600.,
#         2200.,  2300.,  3000.,  1075.,  4500.,  1200.,  2500.,  1050.,
#         1900.,  1250.,  5000.,  2600.,  2900.,  1290.,   850.,  2700.,
#         7000.,  2355.,  3185.,  2400.,  1750.,  1325.,  3535.,   720.,
#         1500.,  1300., 10000.,  6000.,  2080.,  3400.,  1100.,  1650.,
#         1284.,  1800.,   910.,  5200.,  1350.,   600.,  2250.,  1150.,
#         2800.,   870.,  1375.,   995.,   750.,  1825.,  1700.,  1236.,
#          899.,  1695.,  2995.,  8500.,  2100.,  3950.,   950.,  4200.,
#         1850.,  1680.,  4900.,  3450.,  2695.,  2150.,  1600.,  2350.,
#         1000., 11000.,  1061.,  8450.,  2050.,  3200.,  1690.,  1480.,
#         4300.,  3700.,  3550.,  2000.,   700.,  1490.,  1990.,  4150.,
#         1790.,  2490.,  3800.,  6500.,  1675.,  1598.,  2750.,  1820.,
#         4100.,  3900., 11500.,   890.,  4950.,  3100.,  2595.,  3045.,
#         3670.,  2625.,  3425.,   900.,  2935.,  2540.,  1550.,  2475.,
#         4960.,  3340.,  4280.,  4420.,  7800.,  2690.,  2590.,  2850.,
#          990.,  1275.,  3210.,  2375.,  4040.,  3145.,  4235.,  4265.,
#         3570.,  2615.,  2675.,  2620.,  2275.,  2325.,  3675.,  8000.,
#         9500.,  3350.,  3140.,  7500.,  2180.,  3635.,  2660.,  2570.,
#         4460.,  4180.,  3285.,  3645.,  3735.,  4995.,  3070., 15000.,
#         3895.,  3235.,  3515.,  2110.,  4935.,  3330.,  2985.,  3745.,
#         4175.,  2105.,  3890.,   895.,  3945.,  3820.,  2890.,  2875.,
#         2410.,  3220.,  4050.,  4135.,  2260.,  2645.,  8300.,  2015.,
#         2359.,  3640.,  1505.,  2450.,  2665.,  2485.,  2335.,  1495.,
#         2970.,  1224.,  3485.,  3440.,  3755.,  3860.,  3435.,  4065.,
#         2650.,  3395.,  2910.,  3390.,  3180.,  3935.,  6700., 16000.,
#         4520.,  2510.,  3310.,  3520.,  2950.,  9850.,  3540.,  3005.,
#         4185.,  3925.,  3595.,  8900.,  3255.,  2445.,  3930.,  4075.,
#         1230.,  2190.,  2210.,  2435.,  3300.,  3805.,  3030.,  4195.,
#         2575.,  4415.,  5600.,  2010.,  3355.,  4560.,  3770.,  2945.,
#        14000.,  4205.,  3385.,  5400.,  3245.,  4020.,  4225.,  3480.,
#         3810.,  2730.,  6950.,  4055., 10500.,  3690.,  2755.,  4515.,
#         4105.,  3160.,  3490., 12000.,  2920.,  1493.,  4260.,  3250.,
#         4145.,  4390.,  4030.,  3830.,   925.,  3360.,  3910.,  3875.,
#         3730.,  6850.,  2830.,  4125.,  4805.,     0.,  3825., 12500.,
#         2425.,  2385.,  3080.,  3465.,  2960.,  4600.,  2305.,  3225.,
#         2740.,  2585.,  3055.,  2160.,  4070.,  2560.,   955.,  4250.,
#         3660.,  3740.,  4630.,  1045.,  3040.,  4080.,  2725.,  3695.,
#         2745.,  1298.,  3010.,  2630.,  2955.,  4025., 18500.,  3720.,
#         2605.,  2895.,  3095.,  3590.,  8800.,  3125.,  2780.,   650.,
#         4085.,  1950.,   980.,  3150.,  3560.,  2405.,   805.,  3305.,
#         1465.,   800.,   790.,   760.,  4700.,   975.,  1198.,  1295.,
#         9000.,   920.,  1280.,   680.,  6900.,   960.,  2790.,  1155.,
#         1135.,  1170.,  5100.,  1095.,  1195.,  1425.,  1590.,  1020.,
#         4370.,   985.,  1175.,  1240.,  1660.,   935.,  1120.,  1190.,
#         1222.,  1125.,   930.,  1025.,   740.,  2980.,   945.,   860.,
#         1810.,  1070.,  1130.,  6750.,  3990.,   965.,   940.,   905.,
#         1040.,  1080.,  2640., 13500.,  1055.,  1305.,  1005.,   885.,
#         1940.,  2720.,   865.,  1315.,  5900.,  1060.,  1090.,   880.,
#         1865.,  1330.,  3530.,  1010.,  1032.,  1320.,  1127.,  2930.,
#         1145.,  1485.,  1672.,  4800.,  2090.,  1385.,  1625.,  5800.,
#          970.,  2130.,  1685.,   875.,  1185.,  1775.,  1205.,  1435.,
#         1160.,  4750.,  1890.,  1585.,  5700.,  1105.,  1165.,  1360.,
#         2135.,  1015.,  1620.,  6050., 17000.,  1140.,   775.,  2270.,
#         3260.,  1405.,  2030.,  1870.,   915.,  6200.,  4290.,  1565.,
#         2390.,  1395.,  2530.,  1570.,  1540.,  1355., 16500.,  9250.,
#         1235.,  1030.,  1880., 19000.,   830.,  1289.,  8750.,  4620.,
#          999.,  3065.,  2070., 12250.,  1163.,  1390.,  4400.,  6600.,
#         1795.,   595.,  1980.,  1340.,  4350.,  1380.,   780.,   725.,
#         6100.,   450.,   770.,  6800.,  1410.,  1285.,  3650.,  2290.,
#         1520.])

# %%
df_limpio
# Out:
#                                             Descripción  \
# 0             Casa unifamiliar en alquiler en Calle XIX
# 1            Piso en alquiler en Zona Avenida de Europa
# 2     Piso en alquiler en Calle Luis Garcia Cereceda...
# 3           Estudio en alquiler en Calle de Pollensa, 5
# 4     Piso en alquiler en Calle Gran Vía, cerca de C...
# ...                                                 ...
# 2113          Piso en alquiler en Calle del Bidasoa, 16
# 2114         Piso en alquiler en Calle de la Maquinilla
# 2115  Dúplex en alquiler en Avenida de Valdemarín, c...
# 2116                 Piso en alquiler en Cortes-Huertas
# 2117         Piso en alquiler en Calle de los Misterios
#
#                                            Localización  Precio  \
# 0        Las Matas-Los Peñascales (Las Rozas de Madrid)  4000.0
# 1           Zona Avenida de Europa (Pozuelo de Alarcón)  1400.0
# 2                         La Finca (Pozuelo de Alarcón)  5500.0
# 3              Parque Empresarial (Las Rozas de Madrid)  1147.0
# 4     Universidad-Malasaña (Distrito Centro. Madrid ...  3500.0
# ...                                                 ...     ...
# 2113       El Viso (Distrito Chamartín. Madrid Capital)  1450.0
# 2114               ¡Vaya! Esta propiedad no tiene fotos   950.0
# 2115  Valdemarín (Distrito Moncloa-Aravaca. Madrid C...  3900.0
# 2116   Cortes-Huertas (Distrito Centro. Madrid Capital)  1200.0
# 2117  Quintana (Distrito Ciudad Lineal. Madrid Capital)   950.0
#
#      Última Actualización      Consumo Energético  \
# 0              2024-10-28                     NaN
# 1              2024-10-28                     NaN
# 2              2024-10-28   Consumo:15 kWh/m² año
# 3              2024-07-03                     NaN
# 4              2024-10-03   Consumo:70 kWh/m² año
# ...                   ...                     ...
# 2113           2024-10-28                     NaN
# 2114           2024-10-28   Consumo:30 kWh/m² año
# 2115           2024-10-28                     NaN
# 2116           2024-10-28  Consumo:190 kWh/m² año
# 2117           2024-10-28                     NaN
#
#                     Emisiones CO2 Tipo de operación Superficie construida  \
# 0                             NaN          Alquiler                600 m²
# 1                             NaN          Alquiler                 65 m²
# 2       Emisiones:2 Kg CO₂/m² año          Alquiler                190 m²
# 3                             NaN          Alquiler                 50 m²
# 4      Emisiones:15 Kg CO₂/m² año          Alquiler                122 m²
# ...                           ...               ...                   ...
# 2113                          NaN          Alquiler                 60 m²
# 2114  Emisiones:179 Kg CO₂/m² año          Alquiler                 45 m²
# 2115                          NaN          Alquiler                220 m²
# 2116   Emisiones:32 Kg CO₂/m² año          Alquiler                 52 m²
# 2117                          NaN          Alquiler                 38 m²
#
#      Superficie útil Habitaciones Baños          Antigüedad    Conservación  \
# 0             600 m²            6     7   Entre 5 y 10 años  En buen estado
# 1                NaN            1     1                 NaN             NaN
# 2             170 m²            3     3     Menos de 5 años  En buen estado
# 3                NaN          NaN     1                 NaN             NaN
# 4             120 m²            2     2   Entre 5 y 10 años       Reformado
# ...              ...          ...   ...                 ...             ...
# 2113             NaN            1     1  Entre 30 y 50 años  En buen estado
# 2114             NaN            1     1                 NaN  En buen estado
# 2115          170 m²            4     4  Entre 20 y 30 años  En buen estado
# 2116             NaN            2     1      Más de 50 años  En buen estado
# 2117           30 m²          NaN   NaN                 NaN             NaN
#
#      Planta Tipo de Casa
# 0       NaN         Casa
# 1        2ª         Piso
# 2        2ª         Piso
# 3       NaN      Estudio
# 4        8ª         Piso
# ...     ...          ...
# 2113     2ª         Piso
# 2114     3ª         Piso
# 2115     2ª       Dúplex
# 2116     2ª         Piso
# 2117     2ª         Piso
#
# [2118 rows x 15 columns]

# %%
# Rellenar valores nulos en columnas categóricas
df_limpio['Antigüedad'].fillna('No especificado', inplace=True)
df_limpio['Conservación'].fillna('No especificado', inplace=True)
df_limpio['Planta'].fillna('No especificado', inplace=True)
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\911444348.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_limpio['Antigüedad'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\911444348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Antigüedad'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\911444348.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_limpio['Conservación'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\911444348.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Conservación'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\911444348.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_limpio['Planta'].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\911444348.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Planta'].fillna('No especificado', inplace=True)

# %%
 #Convertir 'Superficie construida' y 'Superficie útil' a numérico
df_limpio['Superficie construida'] = df_limpio['Superficie construida'].str.replace(' m²', '').astype(float)
df_limpio['Superficie útil'] = df_limpio['Superficie útil'].str.replace(' m²', '').astype(float)
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\69539082.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Superficie construida'] = df_limpio['Superficie construida'].str.replace(' m²', '').astype(float)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\69539082.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['Superficie útil'] = df_limpio['Superficie útil'].str.replace(' m²', '').astype(float)

# %%
df_limpio
# Out:
#                                             Descripción  \
# 0             Casa unifamiliar en alquiler en Calle XIX
# 1            Piso en alquiler en Zona Avenida de Europa
# 2     Piso en alquiler en Calle Luis Garcia Cereceda...
# 3           Estudio en alquiler en Calle de Pollensa, 5
# 4     Piso en alquiler en Calle Gran Vía, cerca de C...
# ...                                                 ...
# 2113          Piso en alquiler en Calle del Bidasoa, 16
# 2114         Piso en alquiler en Calle de la Maquinilla
# 2115  Dúplex en alquiler en Avenida de Valdemarín, c...
# 2116                 Piso en alquiler en Cortes-Huertas
# 2117         Piso en alquiler en Calle de los Misterios
#
#                                            Localización  Precio  \
# 0        Las Matas-Los Peñascales (Las Rozas de Madrid)  4000.0
# 1           Zona Avenida de Europa (Pozuelo de Alarcón)  1400.0
# 2                         La Finca (Pozuelo de Alarcón)  5500.0
# 3              Parque Empresarial (Las Rozas de Madrid)  1147.0
# 4     Universidad-Malasaña (Distrito Centro. Madrid ...  3500.0
# ...                                                 ...     ...
# 2113       El Viso (Distrito Chamartín. Madrid Capital)  1450.0
# 2114               ¡Vaya! Esta propiedad no tiene fotos   950.0
# 2115  Valdemarín (Distrito Moncloa-Aravaca. Madrid C...  3900.0
# 2116   Cortes-Huertas (Distrito Centro. Madrid Capital)  1200.0
# 2117  Quintana (Distrito Ciudad Lineal. Madrid Capital)   950.0
#
#      Última Actualización      Consumo Energético  \
# 0              2024-10-28                     NaN
# 1              2024-10-28                     NaN
# 2              2024-10-28   Consumo:15 kWh/m² año
# 3              2024-07-03                     NaN
# 4              2024-10-03   Consumo:70 kWh/m² año
# ...                   ...                     ...
# 2113           2024-10-28                     NaN
# 2114           2024-10-28   Consumo:30 kWh/m² año
# 2115           2024-10-28                     NaN
# 2116           2024-10-28  Consumo:190 kWh/m² año
# 2117           2024-10-28                     NaN
#
#                     Emisiones CO2 Tipo de operación  Superficie construida  \
# 0                             NaN          Alquiler                  600.0
# 1                             NaN          Alquiler                   65.0
# 2       Emisiones:2 Kg CO₂/m² año          Alquiler                  190.0
# 3                             NaN          Alquiler                   50.0
# 4      Emisiones:15 Kg CO₂/m² año          Alquiler                  122.0
# ...                           ...               ...                    ...
# 2113                          NaN          Alquiler                   60.0
# 2114  Emisiones:179 Kg CO₂/m² año          Alquiler                   45.0
# 2115                          NaN          Alquiler                  220.0
# 2116   Emisiones:32 Kg CO₂/m² año          Alquiler                   52.0
# 2117                          NaN          Alquiler                   38.0
#
#       Superficie útil Habitaciones Baños          Antigüedad     Conservación  \
# 0               600.0            6     7   Entre 5 y 10 años   En buen estado
# 1                 NaN            1     1     No especificado  No especificado
# 2               170.0            3     3     Menos de 5 años   En buen estado
# 3                 NaN          NaN     1     No especificado  No especificado
# 4               120.0            2     2   Entre 5 y 10 años        Reformado
# ...               ...          ...   ...                 ...              ...
# 2113              NaN            1     1  Entre 30 y 50 años   En buen estado
# 2114              NaN            1     1     No especificado   En buen estado
# 2115            170.0            4     4  Entre 20 y 30 años   En buen estado
# 2116              NaN            2     1      Más de 50 años   En buen estado
# 2117             30.0          NaN   NaN     No especificado  No especificado
#
#                Planta Tipo de Casa
# 0     No especificado         Casa
# 1                  2ª         Piso
# 2                  2ª         Piso
# 3     No especificado      Estudio
# 4                  8ª         Piso
# ...               ...          ...
# 2113               2ª         Piso
# 2114               3ª         Piso
# 2115               2ª       Dúplex
# 2116               2ª         Piso
# 2117               2ª         Piso
#
# [2118 rows x 15 columns]

# %%
df_limpio["Tipo de operación"]
# Out:
# 0       Alquiler
# 1       Alquiler
# 2       Alquiler
# 3       Alquiler
# 4       Alquiler
#           ...
# 2113    Alquiler
# 2114    Alquiler
# 2115    Alquiler
# 2116    Alquiler
# 2117    Alquiler
# Name: Tipo de operación, Length: 2118, dtype: object

# %%
# Eliminar filas duplicadas
df_limpio.drop_duplicates(inplace=True)
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\1072433035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio.drop_duplicates(inplace=True)

# %%
# Usar .title() para capitalizar la primera letra de cada palabra en los nombres de columna
df_limpio.columns = df_limpio.columns.str.title()

# Verificar los nombres de las columnas
print(df_limpio.columns)
# Out:
# Index(['Descripción', 'Localización', 'Precio', 'Última Actualización',
#        'Consumo Energético', 'Emisiones Co2', 'Tipo De Operación',
#        'Superficie Construida', 'Superficie Útil', 'Habitaciones', 'Baños',
#        'Antigüedad', 'Conservación', 'Planta', 'Tipo De Casa'],
#       dtype='object')

# %%
df_limpio["Superficie Útil"].fillna('No especificado', inplace=True)
df_limpio["Habitaciones"].fillna('No especificado', inplace=True)
df_limpio["Baños"].fillna('No especificado', inplace=True)
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\2188569153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["Superficie Útil"].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\2188569153.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_limpio["Habitaciones"].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\2188569153.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["Habitaciones"].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\2188569153.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_limpio["Baños"].fillna('No especificado', inplace=True)
# C:\Users\guill\AppData\Local\Temp\ipykernel_8620\2188569153.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio["Baños"].fillna('No especificado', inplace=True)

# %%
df_limpio
# Out:
#                                             Descripción  \
# 0             Casa unifamiliar en alquiler en Calle XIX
# 1            Piso en alquiler en Zona Avenida de Europa
# 2     Piso en alquiler en Calle Luis Garcia Cereceda...
# 3           Estudio en alquiler en Calle de Pollensa, 5
# 4     Piso en alquiler en Calle Gran Vía, cerca de C...
# ...                                                 ...
# 2113          Piso en alquiler en Calle del Bidasoa, 16
# 2114         Piso en alquiler en Calle de la Maquinilla
# 2115  Dúplex en alquiler en Avenida de Valdemarín, c...
# 2116                 Piso en alquiler en Cortes-Huertas
# 2117         Piso en alquiler en Calle de los Misterios
#
#                                            Localización  Precio  \
# 0        Las Matas-Los Peñascales (Las Rozas de Madrid)  4000.0
# 1           Zona Avenida de Europa (Pozuelo de Alarcón)  1400.0
# 2                         La Finca (Pozuelo de Alarcón)  5500.0
# 3              Parque Empresarial (Las Rozas de Madrid)  1147.0
# 4     Universidad-Malasaña (Distrito Centro. Madrid ...  3500.0
# ...                                                 ...     ...
# 2113       El Viso (Distrito Chamartín. Madrid Capital)  1450.0
# 2114               ¡Vaya! Esta propiedad no tiene fotos   950.0
# 2115  Valdemarín (Distrito Moncloa-Aravaca. Madrid C...  3900.0
# 2116   Cortes-Huertas (Distrito Centro. Madrid Capital)  1200.0
# 2117  Quintana (Distrito Ciudad Lineal. Madrid Capital)   950.0
#
#      Última Actualización      Consumo Energético  \
# 0              2024-10-28                     NaN
# 1              2024-10-28                     NaN
# 2              2024-10-28   Consumo:15 kWh/m² año
# 3              2024-07-03                     NaN
# 4              2024-10-03   Consumo:70 kWh/m² año
# ...                   ...                     ...
# 2113           2024-10-28                     NaN
# 2114           2024-10-28   Consumo:30 kWh/m² año
# 2115           2024-10-28                     NaN
# 2116           2024-10-28  Consumo:190 kWh/m² año
# 2117           2024-10-28                     NaN
#
#                     Emisiones Co2 Tipo De Operación  Superficie Construida  \
# 0                             NaN          Alquiler                  600.0
# 1                             NaN          Alquiler                   65.0
# 2       Emisiones:2 Kg CO₂/m² año          Alquiler                  190.0
# 3                             NaN          Alquiler                   50.0
# 4      Emisiones:15 Kg CO₂/m² año          Alquiler                  122.0
# ...                           ...               ...                    ...
# 2113                          NaN          Alquiler                   60.0
# 2114  Emisiones:179 Kg CO₂/m² año          Alquiler                   45.0
# 2115                          NaN          Alquiler                  220.0
# 2116   Emisiones:32 Kg CO₂/m² año          Alquiler                   52.0
# 2117                          NaN          Alquiler                   38.0
#
#       Superficie Útil     Habitaciones            Baños          Antigüedad  \
# 0               600.0                6                7   Entre 5 y 10 años
# 1     No especificado                1                1     No especificado
# 2               170.0                3                3     Menos de 5 años
# 3     No especificado  No especificado                1     No especificado
# 4               120.0                2                2   Entre 5 y 10 años
# ...               ...              ...              ...                 ...
# 2113  No especificado                1                1  Entre 30 y 50 años
# 2114  No especificado                1                1     No especificado
# 2115            170.0                4                4  Entre 20 y 30 años
# 2116  No especificado                2                1      Más de 50 años
# 2117             30.0  No especificado  No especificado     No especificado
#
#          Conservación           Planta Tipo De Casa
# 0      En buen estado  No especificado         Casa
# 1     No especificado               2ª         Piso
# 2      En buen estado               2ª         Piso
# 3     No especificado  No especificado      Estudio
# 4           Reformado               8ª         Piso
# ...               ...              ...          ...
# 2113   En buen estado               2ª         Piso
# 2114   En buen estado               3ª         Piso
# 2115   En buen estado               2ª       Dúplex
# 2116   En buen estado               2ª         Piso
# 2117  No especificado               2ª         Piso
#
# [2109 rows x 15 columns]
