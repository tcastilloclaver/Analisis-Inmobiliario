# %% [markdown]
# # Placeholders

# %%
import streamlit as st

# Título principal de la aplicación
st.title("Análisis del Mercado Inmobiliario: Ratio de Compra vs. Alquiler")

# Sección 1: Resumen General
st.header("Vista General del Análisis")
st.write("Aquí se mostrarán los hallazgos clave del mercado, incluyendo el ratio promedio de compra a alquiler, "
         "tipos de propiedades con ratios favorables y un análisis general de los precios.")

# Placeholder para métricas clave
st.subheader("Métricas Clave")
st.metric(label="Promedio Ratio Compra/Alquiler", value="Placeholder")
st.metric(label="Precio Promedio de Compra", value="Placeholder")
st.metric(label="Precio Promedio de Alquiler", value="Placeholder")

# Sección 2: Análisis de Segmentación por Tipo de Propiedad y Habitaciones
st.header("Segmentación por Tipo de Propiedad y Habitaciones")
st.write("Este análisis examinará cómo cada tipo de propiedad y el número de habitaciones afectan el ratio de compra a alquiler.")

# Placeholder para gráficos
st.subheader("Gráfico de Ratios por Tipo de Propiedad y Habitaciones")
st.write("Gráfico de barras que muestra el ratio promedio para cada combinación de tipo de propiedad y número de habitaciones.")
# Aquí se podría usar un gráfico placeholder, por ejemplo:
st.image("https://via.placeholder.com/600x400", caption="Gráfico de Ratios Placeholder")

st.subheader("Distribución de Precios de Alquiler y Compra por Segmento")
st.write("Diagrama de caja que muestra la distribución de precios para diferentes tipos de propiedad.")
st.image("https://via.placeholder.com/600x400", caption="Diagrama de Caja Placeholder")

# Sección 3: Distribución Geográfica de Ratios
st.header("Distribución Geográfica del Ratio Compra/Alquiler")
st.write("En esta sección se analizarán los ratios de compra/alquiler según la ubicación.")

# Placeholder para mapas
st.subheader("Mapa de Calor del Ratio Compra/Alquiler")
st.write("Mapa de calor que muestra las zonas con ratios más favorables.")
st.image("https://via.placeholder.com/600x400", caption="Mapa de Calor Placeholder")

st.subheader("Mapa de Distribución de Precios")
st.write("Mapa de distribución de precios de compra y alquiler en diferentes zonas.")
st.image("https://via.placeholder.com/600x400", caption="Mapa de Distribución Placeholder")

# Sección 4: Conclusiones y Recomendaciones
st.header("Conclusiones y Recomendaciones de Inversión")
st.write("Aquí se incluirán recomendaciones finales sobre las ubicaciones y tipos de propiedad más favorables "
         "para inversión según el análisis de ratio compra/alquiler.")

st.write("**Nota:** Esta aplicación aún está en desarrollo; los gráficos y mapas se agregarán en versiones futuras.")
# Out:
# 2024-10-30 21:36:34.999 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-30 21:36:35.074
# ...
#   command:
#
#     streamlit run /opt/anaconda3/envs/.env/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-10-30 21:36:35.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-30 21:36:35.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-30 21:36:35.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-30 21:36:35.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-30 21:36:35.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
